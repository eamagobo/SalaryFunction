# %%
#importing the pandas
import pandas as pd

# %%
#load and lead the csv file to jupyter notebook
data = pd.read_csv("Total.csv")
# Out:
# C:\Users\ElishaAbelMagobo\AppData\Local\Temp\ipykernel_12548\4280927128.py:1: DtypeWarning: Columns (2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Total.csv")

# %%
#calling for data to display the first and last few columns and rows
data
# Out:
#               EmployeeName                                        JobTitle  \
# 0           NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1             GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2           ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3        CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4          PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                    ...                                             ...
# 312877     Daniel W Plautz                          Public Service Trainee
# 312878    David J Thompson                                  Deputy Sheriff
# 312879  Keiko Weng Yee Lau                          Public Service Trainee
# 312880          David Wong                                  Deputy Sheriff
# 312881     Debora E Howard                               Recreation Leader
#
#           BasePay OvertimePay   OtherPay      Benefits   TotalPay  \
# 0       167411.18         0.0  400184.25  Not Provided  567595.43
# 1       155966.02   245131.88  137811.38  Not Provided  538909.28
# 2       212739.13   106088.18    16452.6  Not Provided  335279.91
# 3         77916.0    56120.71   198306.9  Not Provided  332343.61
# 4        134401.6      9737.0  182234.59  Not Provided  326373.19
# ...           ...         ...        ...           ...        ...
# 312877        0.0         0.0        0.0           0.0       0.00
# 312878        0.0         0.0        0.0           0.0       0.00
# 312879        0.0         0.0        0.0           0.0       0.00
# 312880        0.0         0.0        0.0           0.0       0.00
# 312881        0.0         0.0        0.0           0.0       0.00
#
#         TotalPayBenefits  Year
# 0              567595.43  2011
# 1              538909.28  2011
# 2              335279.91  2011
# 3              332343.61  2011
# 4              326373.19  2011
# ...                  ...   ...
# 312877              0.00  2018
# 312878              0.00  2018
# 312879              0.00  2018
# 312880              0.00  2018
# 312881              0.00  2018
#
# [312882 rows x 9 columns]

# %%
#developing the python function that accepts an employee's name as input and return their details
data['TotalPay']
# Out:
# 0         567595.43
# 1         538909.28
# 2         335279.91
# 3         332343.61
# 4         326373.19
#             ...
# 312877         0.00
# 312878         0.00
# 312879         0.00
# 312880         0.00
# 312881         0.00
# Name: TotalPay, Length: 312882, dtype: float64

# %%
# python function with input of name and return details of the employees

def employee_details(name, title, base_pay, overtime_pay, other_pay, benefits, total_pay, total_pay_benefits, year):
    return f"Employee_details: employee_name: {name}, Job Title: {title}, Base Pay: {base_pay}, Overtime Pay: {overtime_pay}, Other Pay: {other_pay}, Benefits: {benefits}, Total Pay: {total_pay}, Total Pay Benefits: {total_pay_benefits}, Year: {year}"
print(employee_details('NATHANIEL FORD', 'GENERAL MANAGER', 167411.18, 0.0, 400184.25, 'Not provided', 567595.43, 567595.43, 2011))
# Out:
# Employee_details: employee_name: NATHANIEL FORD, Job Title: GENERAL MANAGER, Base Pay: 167411.18, Overtime Pay: 0.0, Other Pay: 400184.25, Benefits: Not provided, Total Pay: 567595.43, Total Pay Benefits: 567595.43, Year: 2011

# %%
# if you want to display employee details on a separate line use the \n function before the input

def employee_details(name, title, base_pay, overtime_pay, other_pay, benefits, total_pay, total_pay_benefits, year):
    return f"Employee_details: employee_name: \n {name}, \n Job Title: {title}, \n Base Pay: {base_pay}, \n Overtime Pay: {overtime_pay}, \n Other Pay: {other_pay}, \n Benefits: {benefits}, \n Total Pay: {total_pay}, \n Total Pay Benefits: {total_pay_benefits}, \n Year: {year} "
print(employee_details('NATHANIEL FORD', 'GENERAL MANAGER', 167411.18, 0.0, 400184.25, 'Not provided', 567595.43, 567595.43, 2011))
# Out:
# Employee_details: employee_name:
#  NATHANIEL FORD,
#  Job Title: GENERAL MANAGER,
#  Base Pay: 167411.18,
#  Overtime Pay: 0.0,
#  Other Pay: 400184.25,
#  Benefits: Not provided,
#  Total Pay: 567595.43,
#  Total Pay Benefits: 567595.43,
#  Year: 2011

# %%
import pandas as pd

# Load the salary data file
file_path = "Total.csv"
df = pd.read_csv(file_path)

# Convert "Not Provided" to NaN
df.replace("Not Provided", pd.NA, inplace=True)

# Convert salary-related columns to numeric values
salary_columns = ["BasePay", "OvertimePay", "OtherPay", "TotalPay", "TotalPayBenefits"]
df[salary_columns] = df[salary_columns].apply(pd.to_numeric, errors="coerce")

# Create a salary dictionary
salary_dict = {}
for _, row in df.iterrows():
    name = row["EmployeeName"]
    record = {
        "JobTitle": row["JobTitle"],
        "BasePay": row["BasePay"],
        "OvertimePay": row["OvertimePay"],
        "OtherPay": row["OtherPay"],
        "TotalPay": row["TotalPay"],
        "TotalPayBenefits": row["TotalPayBenefits"],
        "Year": row["Year"],
    }
    
    if name in salary_dict:
        salary_dict[name].append(record)
    else:
        salary_dict[name] = [record]

# Display a sample entry
print(list(salary_dict.items())[:3])
# Out:
# C:\Users\ElishaAbelMagobo\AppData\Local\Temp\ipykernel_12548\1392520525.py:5: DtypeWarning: Columns (2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# [('NATHANIEL FORD', [{'JobTitle': 'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', 'BasePay': 167411.18, 'OvertimePay': 0.0, 'OtherPay': 400184.25, 'TotalPay': 567595.43, 'TotalPayBenefits': 567595.43, 'Year': 2011}]), ('GARY JIMENEZ', [{'JobTitle': 'CAPTAIN III (POLICE DEPARTMENT)', 'BasePay': 155966.02, 'OvertimePay': 245131.88, 'OtherPay': 137811.38, 'TotalPay': 538909.28, 'TotalPayBenefits': 538909.28, 'Year': 2011}]), ('ALBERT PARDINI', [{'JobTitle': 'CAPTAIN III (POLICE DEPARTMENT)', 'BasePay': 212739.13, 'OvertimePay': 106088.18, 'OtherPay': 16452.6, 'TotalPay': 335279.91, 'TotalPayBenefits': 335279.91, 'Year': 2011}])]

# %%
salary_dict
# Out:
# {'NATHANIEL FORD': [{'JobTitle': 'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#    'BasePay': 167411.18,
#    'OvertimePay': 0.0,
#    'OtherPay': 400184.25,
#    'TotalPay': 567595.43,
#    'TotalPayBenefits': 567595.43,
#    'Year': 2011}],
#  'GARY JIMENEZ': [{'JobTitle': 'CAPTAIN III (POLICE DEPARTMENT)',
#    'BasePay': 155966.02,
#    'OvertimePay': 245131.88,
#    'OtherPay': 137811.38,
#    'TotalPay': 538909.28,
#    'TotalPayBenefits': 538909.28,
#    'Year': 2011}],
#  'ALBERT PARDINI': [{'JobTitle': 'CAPTAIN III (POLICE DEPARTMENT)',
#    'BasePay': 212739.13,
#    'OvertimePay': 106088.18,
#    'OtherPay': 16452.6,
#    'TotalPay': 335279.91,
#    'TotalPayBenefits': 335279.91,
#    'Year': 2011}],
#  'CHRISTOPHER CHONG': [{'JobTitle': 'WIRE ROPE CABLE MAINTENANCE MECHANIC',
#    'BasePay': 77916.0,
#    'OvertimePay': 56120.71,
#    'OtherPay': 198306.9,
#    'TotalPay': 332343.61,
#    'TotalPayBenefits': 332343.61,
#    'Year': 2011}],
#  'PATRICK GARDNER': [{'JobTitle': 'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)',
#    'BasePay': 134401.6,
#    'OvertimePay': 9737.0,
#    'OtherPay': 182234.59,
#    'TotalPay': 326373.19,
#    'TotalPayBenefits': 326373.19,
#    'Year': 2011}],
#  'DAVID SULLIVAN': [{'JobTitle': 'ASSISTANT DEPUTY CHIEF II',
#    'BasePay': 118602.0,
#    'OvertimePay': 8601.0,
#    'OtherPay': 189082.74,
#    'TotalPay': 316285.74,
#    'TotalPayBenefits': 316285.74,
#    'Year': 2011},
#   {'JobTitle': 'PLANNER III',
#    'BasePay': 94758.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 1716.92,
#    'TotalPay': 96474.92,
#    'TotalPayBenefits': 96474.92,
#    'Year': 2011}],
#  'ALSON LEE': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 92492.01,
#    'OvertimePay': 89062.9,
#    'OtherPay': 134426.14,
#    'TotalPay': 315981.05,
#    'TotalPayBenefits': 315981.05,
#    'Year': 2011}],
#  'DAVID KUSHNER': [{'JobTitle': 'DEPUTY DIRECTOR OF INVESTMENTS',
#    'BasePay': 256576.96,
#    'OvertimePay': 0.0,
#    'OtherPay': 51322.5,
#    'TotalPay': 307899.46,
#    'TotalPayBenefits': 307899.46,
#    'Year': 2011}],
#  'MICHAEL MORRIS': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 176932.64,
#    'OvertimePay': 86362.68,
#    'OtherPay': 40132.23,
#    'TotalPay': 303427.55,
#    'TotalPayBenefits': 303427.55,
#    'Year': 2011},
#   {'JobTitle': 'TRUCK DRIVER',
#    'BasePay': 67127.89,
#    'OvertimePay': 110.67,
#    'OtherPay': 1750.25,
#    'TotalPay': 68988.81,
#    'TotalPayBenefits': 68988.81,
#    'Year': 2011}],
#  'JOANNE HAYES-WHITE': [{'JobTitle': 'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#    'BasePay': 285262.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 17115.73,
#    'TotalPay': 302377.73,
#    'TotalPayBenefits': 302377.73,
#    'Year': 2011}],
#  'ARTHUR KENNEY': [{'JobTitle': 'ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#    'BasePay': 194999.39,
#    'OvertimePay': 71344.88,
#    'OtherPay': 33149.9,
#    'TotalPay': 299494.17,
#    'TotalPayBenefits': 299494.17,
#    'Year': 2011}],
#  'PATRICIA JACKSON': [{'JobTitle': 'CAPTAIN III (POLICE DEPARTMENT)',
#    'BasePay': 99722.0,
#    'OvertimePay': 87082.62,
#    'OtherPay': 110804.3,
#    'TotalPay': 297608.92,
#    'TotalPayBenefits': 297608.92,
#    'Year': 2011}],
#  'EDWARD HARRINGTON': [{'JobTitle': 'EXECUTIVE CONTRACT EMPLOYEE',
#    'BasePay': 294580.02,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 294580.02,
#    'TotalPayBenefits': 294580.02,
#    'Year': 2011}],
#  'JOHN MARTIN': [{'JobTitle': 'DEPARTMENT HEAD V',
#    'BasePay': 271329.03,
#    'OvertimePay': 0.0,
#    'OtherPay': 21342.59,
#    'TotalPay': 292671.62,
#    'TotalPayBenefits': 292671.62,
#    'Year': 2011},
#   {'JobTitle': 'STATIONARY ENGINEER, SEWAGE PLANT',
#    'BasePay': 72991.21,
#    'OvertimePay': 3063.04,
#    'OtherPay': 5760.83,
#    'TotalPay': 81815.08,
#    'TotalPayBenefits': 81815.08,
#    'Year': 2011},
#   {'JobTitle': 'ELECTIONS WORKER',
#    'BasePay': 52123.0,
#    'OvertimePay': 2638.75,
#    'OtherPay': 0.0,
#    'TotalPay': 54761.75,
#    'TotalPayBenefits': 54761.75,
#    'Year': 2011},
#   {'JobTitle': 'RECREATION LEADER',
#    'BasePay': 526.3,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 526.3,
#    'TotalPayBenefits': 526.3,
#    'Year': 2011}],
#  'DAVID FRANKLIN': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 174872.64,
#    'OvertimePay': 74050.3,
#    'OtherPay': 37424.11,
#    'TotalPay': 286347.05,
#    'TotalPayBenefits': 286347.05,
#    'Year': 2011}],
#  'RICHARD CORRIEA': [{'JobTitle': 'COMMANDER III, (POLICE DEPARTMENT)',
#    'BasePay': 198778.01,
#    'OvertimePay': 73478.2,
#    'OtherPay': 13957.65,
#    'TotalPay': 286213.86,
#    'TotalPayBenefits': 286213.86,
#    'Year': 2011}],
#  'AMY HART': [{'JobTitle': 'DEPARTMENT HEAD V',
#    'BasePay': 268604.57,
#    'OvertimePay': 0.0,
#    'OtherPay': 16115.86,
#    'TotalPay': 284720.43,
#    'TotalPayBenefits': 284720.43,
#    'Year': 2011}],
#  'SEBASTIAN WONG': [{'JobTitle': 'CAPTAIN, EMERGENCYCY MEDICAL SERVICES',
#    'BasePay': 140546.87,
#    'OvertimePay': 119397.26,
#    'OtherPay': 18625.08,
#    'TotalPay': 278569.21,
#    'TotalPayBenefits': 278569.21,
#    'Year': 2011}],
#  'MARTY ROSS': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 168692.63,
#    'OvertimePay': 69626.12,
#    'OtherPay': 38115.47,
#    'TotalPay': 276434.22,
#    'TotalPayBenefits': 276434.22,
#    'Year': 2011}],
#  'ELLEN MOFFATT': [{'JobTitle': 'ASSISTANT MEDICAL EXAMINER',
#    'BasePay': 257510.59,
#    'OvertimePay': 880.16,
#    'OtherPay': 16159.5,
#    'TotalPay': 274550.25,
#    'TotalPayBenefits': 274550.25,
#    'Year': 2011}],
#  'VENUS AZAR': [{'JobTitle': 'ASSISTANT MEDICAL EXAMINER',
#    'BasePay': 257510.48,
#    'OvertimePay': 0.0,
#    'OtherPay': 16679.79,
#    'TotalPay': 274190.27,
#    'TotalPayBenefits': 274190.27,
#    'Year': 2011}],
#  'JUDY MELINEK': [{'JobTitle': 'ASSISTANT MEDICAL EXAMINER',
#    'BasePay': 257510.44,
#    'OvertimePay': 377.21,
#    'OtherPay': 15883.56,
#    'TotalPay': 273771.21,
#    'TotalPayBenefits': 273771.21,
#    'Year': 2011}],
#  'GEORGE GARCIA': [{'JobTitle': 'CAPTAIN, FIRE SUPPRESSION',
#    'BasePay': 140546.88,
#    'OvertimePay': 93200.58,
#    'OtherPay': 39955.25,
#    'TotalPay': 273702.71,
#    'TotalPayBenefits': 273702.71,
#    'Year': 2011}],
#  'VICTOR WYRSCH': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 168692.63,
#    'OvertimePay': 77896.14,
#    'OtherPay': 24083.86,
#    'TotalPay': 270672.63,
#    'TotalPayBenefits': 270672.63,
#    'Year': 2011}],
#  'JOSEPH DRISCOLL': [{'JobTitle': 'CAPTAIN, FIRE SUPPRESSION',
#    'BasePay': 140546.86,
#    'OvertimePay': 97868.77,
#    'OtherPay': 31909.28,
#    'TotalPay': 270324.91,
#    'TotalPayBenefits': 270324.91,
#    'Year': 2011}],
#  'GREGORY SUHR': [{'JobTitle': 'CHIEF OF POLICE',
#    'BasePay': 256470.41,
#    'OvertimePay': 0.0,
#    'OtherPay': 11522.18,
#    'TotalPay': 267992.59,
#    'TotalPayBenefits': 267992.59,
#    'Year': 2011}],
#  'JOHN HANLEY': [{'JobTitle': 'CAPTAIN, FIRE SUPPRESSION',
#    'BasePay': 92080.8,
#    'OvertimePay': 40008.0,
#    'OtherPay': 133695.76,
#    'TotalPay': 265784.56,
#    'TotalPayBenefits': 265784.56,
#    'Year': 2011}],
#  'RAYMOND GUZMAN': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 168692.59,
#    'OvertimePay': 80706.88,
#    'OtherPay': 16063.99,
#    'TotalPay': 265463.46,
#    'TotalPayBenefits': 265463.46,
#    'Year': 2011}],
#  'DENISE SCHMITT': [{'JobTitle': 'DEPUTY CHIEF III (POLICE DEPARTMENT)',
#    'BasePay': 261717.6,
#    'OvertimePay': 0.0,
#    'OtherPay': 2357.0,
#    'TotalPay': 264074.6,
#    'TotalPayBenefits': 264074.6,
#    'Year': 2011}],
#  'MONICA FIELDS': [{'JobTitle': 'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)',
#    'BasePay': 246225.6,
#    'OvertimePay': 0.0,
#    'OtherPay': 15140.54,
#    'TotalPay': 261366.14,
#    'TotalPayBenefits': 261366.14,
#    'Year': 2011}],
#  'HARLAN KELLY-JR': [{'JobTitle': 'EXECUTIVE CONTRACT EMPLOYEE',
#    'BasePay': 234325.02,
#    'OvertimePay': 0.0,
#    'OtherPay': 25972.64,
#    'TotalPay': 260297.66,
#    'TotalPayBenefits': 260297.66,
#    'Year': 2011}],
#  'DAVID SHINN': [{'JobTitle': 'DEPUTY CHIEF III (POLICE DEPARTMENT)',
#    'BasePay': 254027.63,
#    'OvertimePay': 0.0,
#    'OtherPay': 5899.48,
#    'TotalPay': 259927.11,
#    'TotalPayBenefits': 259927.11,
#    'Year': 2011}],
#  'GARY AMELIO': [{'JobTitle': 'DEPARTMENT HEAD V',
#    'BasePay': 248895.7,
#    'OvertimePay': 0.0,
#    'OtherPay': 10789.18,
#    'TotalPay': 259684.88,
#    'TotalPayBenefits': 259684.88,
#    'Year': 2011}],
#  'JOHN TURSI': [{'JobTitle': 'INSPECTOR III, (POLICE DEPARTMENT)',
#    'BasePay': 104861.39,
#    'OvertimePay': 50227.61,
#    'OtherPay': 103499.39,
#    'TotalPay': 258588.39,
#    'TotalPayBenefits': 258588.39,
#    'Year': 2011},
#   {'JobTitle': 'POLICE OFFICER III',
#    'BasePay': 6781.25,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 6781.25,
#    'TotalPayBenefits': 6781.25,
#    'Year': 2011}],
#  'JOSE VELO': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 177781.25,
#    'OvertimePay': 59924.97,
#    'OtherPay': 20658.0,
#    'TotalPay': 258364.22,
#    'TotalPayBenefits': 258364.22,
#    'Year': 2011}],
#  'KHOA TRINH': [{'JobTitle': 'ELECTRONIC MAINTENANCE TECHNICIAN',
#    'BasePay': 101953.2,
#    'OvertimePay': 139102.95,
#    'OtherPay': 16483.94,
#    'TotalPay': 257540.09,
#    'TotalPayBenefits': 257540.09,
#    'Year': 2011}],
#  'SUSAN CURRIN': [{'JobTitle': 'ADMINISTRATOR, SFGH MEDICAL CENTER',
#    'BasePay': 245124.44,
#    'OvertimePay': 0.0,
#    'OtherPay': 12000.0,
#    'TotalPay': 257124.44,
#    'TotalPayBenefits': 257124.44,
#    'Year': 2011}],
#  'JAMES BOSCH': [{'JobTitle': 'INSPECTOR III, (POLICE DEPARTMENT)',
#    'BasePay': 110661.2,
#    'OvertimePay': 31162.04,
#    'OtherPay': 111446.2,
#    'TotalPay': 253269.44,
#    'TotalPayBenefits': 253269.44,
#    'Year': 2011}],
#  'JONES WONG': [{'JobTitle': 'LIEUTENANT III (POLICE DEPARTMENT)',
#    'BasePay': 132202.26,
#    'OvertimePay': 52648.92,
#    'OtherPay': 67083.83,
#    'TotalPay': 251935.01,
#    'TotalPayBenefits': 251935.01,
#    'Year': 2011}],
#  'BRENDAN WARD': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 147158.85,
#    'OvertimePay': 64985.85,
#    'OtherPay': 39540.46,
#    'TotalPay': 251685.16,
#    'TotalPayBenefits': 251685.16,
#    'Year': 2011}],
#  'MICHAEL THOMPSON': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 168692.66,
#    'OvertimePay': 60847.56,
#    'OtherPay': 21055.17,
#    'TotalPay': 250595.39,
#    'TotalPayBenefits': 250595.39,
#    'Year': 2011},
#   {'JobTitle': 'FIREFIGHTER',
#    'BasePay': 123013.02,
#    'OvertimePay': 111729.65,
#    'OtherPay': 15575.26,
#    'TotalPay': 250317.93,
#    'TotalPayBenefits': 250317.93,
#    'Year': 2011}],
#  'THOMAS ABBOTT': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 168692.63,
#    'OvertimePay': 59760.9,
#    'OtherPay': 21954.96,
#    'TotalPay': 250408.49,
#    'TotalPayBenefits': 250408.49,
#    'Year': 2011}],
#  'THOMAS SIRAGUSA': [{'JobTitle': 'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)',
#    'BasePay': 218930.76,
#    'OvertimePay': 4078.0,
#    'OtherPay': 27330.59,
#    'TotalPay': 250339.35,
#    'TotalPayBenefits': 250339.35,
#    'Year': 2011}],
#  'SHARON MCCOLE WICHER': [{'JobTitle': 'NURSING SUPERVISOR PSYCHIATRIC',
#    'BasePay': 196081.86,
#    'OvertimePay': 0.0,
#    'OtherPay': 54040.18,
#    'TotalPay': 250122.04,
#    'TotalPayBenefits': 250122.04,
#    'Year': 2011},
#   {'JobTitle': 'NURSING SUPERVISOR',
#    'BasePay': 20322.4,
#    'OvertimePay': 0.0,
#    'OtherPay': 2032.24,
#    'TotalPay': 22354.64,
#    'TotalPayBenefits': 22354.64,
#    'Year': 2011}],
#  'EDWIN LEE': [{'JobTitle': 'MAYOR',
#    'BasePay': 249375.02,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 249375.02,
#    'TotalPayBenefits': 249375.02,
#    'Year': 2011},
#   {'JobTitle': 'POLICE OFFICER II',
#    'BasePay': 102599.12,
#    'OvertimePay': 6326.86,
#    'OtherPay': 6894.49,
#    'TotalPay': 115820.47,
#    'TotalPayBenefits': 115820.47,
#    'Year': 2011},
#   {'JobTitle': 'SENIOR ACCOUNTANT',
#    'BasePay': 62464.54,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 62464.54,
#    'TotalPayBenefits': 62464.54,
#    'Year': 2011}],
#  'BRYAN RUBENSTEIN': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 168692.64,
#    'OvertimePay': 66199.23,
#    'OtherPay': 14401.43,
#    'TotalPay': 249293.3,
#    'TotalPayBenefits': 249293.3,
#    'Year': 2011}],
#  'TRENT RHORER': [{'JobTitle': 'DEPARTMENT HEAD V',
#    'BasePay': 248895.77,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 248895.77,
#    'TotalPayBenefits': 248895.77,
#    'Year': 2011}],
#  'JAMES DUDLEY': [{'JobTitle': 'DEPUTY CHIEF III (POLICE DEPARTMENT)',
#    'BasePay': 233867.6,
#    'OvertimePay': 0.0,
#    'OtherPay': 14851.04,
#    'TotalPay': 248718.64,
#    'TotalPayBenefits': 248718.64,
#    'Year': 2011}],
#  'KEN YEE': [{'JobTitle': 'LIEUTENANT, FIRE DEPARTMENT',
#    'BasePay': 137729.92,
#    'OvertimePay': 89856.01,
#    'OtherPay': 20848.46,
#    'TotalPay': 248434.39,
#    'TotalPayBenefits': 248434.39,
#    'Year': 2011}],
#  'KIRK RICHARDSON': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 168692.59,
#    'OvertimePay': 58084.86,
#    'OtherPay': 20477.16,
#    'TotalPay': 247254.61,
#    'TotalPayBenefits': 247254.61,
#    'Year': 2011}],
#  'BARBARA GARCIA': [{'JobTitle': 'DEPARTMENT HEAD V',
#    'BasePay': 246305.62,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 246305.62,
#    'TotalPayBenefits': 246305.62,
#    'Year': 2011}],
#  'MICHAEL ROLOVICH': [{'JobTitle': 'CAPTAIN, FIRE SUPPRESSION',
#    'BasePay': 140546.87,
#    'OvertimePay': 77937.25,
#    'OtherPay': 26203.69,
#    'TotalPay': 244687.81,
#    'TotalPayBenefits': 244687.81,
#    'Year': 2011}],
#  'DARRYL HUNTER': [{'JobTitle': 'CAPTAIN, FIRE SUPPRESSION',
#    'BasePay': 140546.88,
#    'OvertimePay': 73207.61,
#    'OtherPay': 28988.36,
#    'TotalPay': 242742.85,
#    'TotalPayBenefits': 242742.85,
#    'Year': 2011}],
#  'RAY CRAWFORD': [{'JobTitle': 'CAPTAIN, EMERGENCYCY MEDICAL SERVICES',
#    'BasePay': 140546.89,
#    'OvertimePay': 82428.76,
#    'OtherPay': 18310.77,
#    'TotalPay': 241286.42,
#    'TotalPayBenefits': 241286.42,
#    'Year': 2011}],
#  'KEVIN CASHMAN': [{'JobTitle': 'DEPUTY CHIEF III (POLICE DEPARTMENT)',
#    'BasePay': 226206.8,
#    'OvertimePay': 0.0,
#    'OtherPay': 15004.37,
#    'TotalPay': 241211.17,
#    'TotalPayBenefits': 241211.17,
#    'Year': 2011}],
#  'BENJAMIN ROSENFIELD': [{'JobTitle': 'DEPARTMENT HEAD V',
#    'BasePay': 240731.93,
#    'OvertimePay': 0.0,
#    'OtherPay': 114.37,
#    'TotalPay': 240846.3,
#    'TotalPayBenefits': 240846.3,
#    'Year': 2011}],
#  'MARK KEARNEY': [{'JobTitle': 'ASSISTANT DEPUTY CHIEF II',
#    'BasePay': 217410.8,
#    'OvertimePay': 0.0,
#    'OtherPay': 22608.3,
#    'TotalPay': 240019.1,
#    'TotalPayBenefits': 240019.1,
#    'Year': 2011}],
#  'DOUGLAS RIBA': [{'JobTitle': 'INCIDENT SUPPORT SPECIALIST',
#    'BasePay': 115381.02,
#    'OvertimePay': 105028.94,
#    'OtherPay': 19016.4,
#    'TotalPay': 239426.36,
#    'TotalPayBenefits': 239426.36,
#    'Year': 2011}],
#  'AI-KYUNG CHUNG': [{'JobTitle': 'ANESTHETIST',
#    'BasePay': 214745.44,
#    'OvertimePay': 9161.31,
#    'OtherPay': 14972.45,
#    'TotalPay': 238879.2,
#    'TotalPayBenefits': 238879.2,
#    'Year': 2011}],
#  'KENNETH SMITH': [{'JobTitle': 'LIEUTENANT, FIRE DEPARTMENT',
#    'BasePay': 123105.0,
#    'OvertimePay': 99584.94,
#    'OtherPay': 16113.62,
#    'TotalPay': 238803.56,
#    'TotalPayBenefits': 238803.56,
#    'Year': 2011},
#   {'JobTitle': 'PARKING CONTROL OFFICER',
#    'BasePay': 55429.65,
#    'OvertimePay': 10689.32,
#    'OtherPay': 1451.03,
#    'TotalPay': 67570.0,
#    'TotalPayBenefits': 67570.0,
#    'Year': 2011}],
#  'ANNA BROWN': [{'JobTitle': 'CAPTAIN III (POLICE DEPARTMENT)',
#    'BasePay': 102571.24,
#    'OvertimePay': 7437.0,
#    'OtherPay': 128543.64,
#    'TotalPay': 238551.88,
#    'TotalPayBenefits': 238551.88,
#    'Year': 2011}],
#  'JAMES FAZACKERLEY': [{'JobTitle': 'CAPTAIN, EMERGENCYCY MEDICAL SERVICES',
#    'BasePay': 140546.86,
#    'OvertimePay': 80411.9,
#    'OtherPay': 17542.29,
#    'TotalPay': 238501.05,
#    'TotalPayBenefits': 238501.05,
#    'Year': 2011}],
#  'CHARLES CRANE': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 168692.62,
#    'OvertimePay': 54342.28,
#    'OtherPay': 15444.38,
#    'TotalPay': 238479.28,
#    'TotalPayBenefits': 238479.28,
#    'Year': 2011}],
#  'GREGORY MAR': [{'JobTitle': 'LIEUTENANT III (POLICE DEPARTMENT)',
#    'BasePay': 148970.43,
#    'OvertimePay': 66977.63,
#    'OtherPay': 21889.67,
#    'TotalPay': 237837.73,
#    'TotalPayBenefits': 237837.73,
#    'Year': 2011}],
#  'RICHARD PARRY': [{'JobTitle': 'CAPTAIN III (POLICE DEPARTMENT)',
#    'BasePay': 185369.69,
#    'OvertimePay': 37873.61,
#    'OtherPay': 14465.53,
#    'TotalPay': 237708.83,
#    'TotalPayBenefits': 237708.83,
#    'Year': 2011}],
#  'ROBERT POSTEL': [{'JobTitle': 'ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#    'BasePay': 177914.76,
#    'OvertimePay': 36644.57,
#    'OtherPay': 22785.08,
#    'TotalPay': 237344.41,
#    'TotalPayBenefits': 237344.41,
#    'Year': 2011}],
#  'EDWARD ROLAND': [{'JobTitle': 'CAPTAIN, FIRE SUPPRESSION',
#    'BasePay': 139167.39,
#    'OvertimePay': 66596.28,
#    'OtherPay': 31070.15,
#    'TotalPay': 236833.82,
#    'TotalPayBenefits': 236833.82,
#    'Year': 2011}],
#  'THOMAS SHAWYER': [{'JobTitle': 'DEPUTY CHIEF III (POLICE DEPARTMENT)',
#    'BasePay': 122974.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 113226.92,
#    'TotalPay': 236200.92,
#    'TotalPayBenefits': 236200.92,
#    'Year': 2011}],
#  'WING CHAN': [{'JobTitle': 'INCIDENT SUPPORT SPECIALIST',
#    'BasePay': 115455.44,
#    'OvertimePay': 104632.95,
#    'OtherPay': 14776.81,
#    'TotalPay': 234865.2,
#    'TotalPayBenefits': 234865.2,
#    'Year': 2011},
#   {'JobTitle': 'LIBRARIAN II',
#    'BasePay': 76779.51,
#    'OvertimePay': 0.0,
#    'OtherPay': 1569.76,
#    'TotalPay': 78349.27,
#    'TotalPayBenefits': 78349.27,
#    'Year': 2011}],
#  'GEORGE GASCON': [{'JobTitle': 'DISTRICT ATTORNEY',
#    'BasePay': 220983.12,
#    'OvertimePay': 0.0,
#    'OtherPay': 13864.99,
#    'TotalPay': 234848.11,
#    'TotalPayBenefits': 234848.11,
#    'Year': 2011}],
#  'RICHARD BUSALACCHI': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 92782.61,
#    'OvertimePay': 5477.62,
#    'OtherPay': 135684.25,
#    'TotalPay': 233944.48,
#    'TotalPayBenefits': 233944.48,
#    'Year': 2011}],
#  'LAWRENCE FREED': [{'JobTitle': 'ELECTRICAL TRANSIT MECHANIC, ASSISTANT SUPERVISOR',
#    'BasePay': 95770.8,
#    'OvertimePay': 118949.93,
#    'OtherPay': 18743.9,
#    'TotalPay': 233464.63,
#    'TotalPayBenefits': 233464.63,
#    'Year': 2011}],
#  'MONIQUE MOYER': [{'JobTitle': 'PORT DIRECTOR',
#    'BasePay': 233357.28,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 233357.28,
#    'TotalPayBenefits': 233357.28,
#    'Year': 2011}],
#  'ANTONIO FLORES': [{'JobTitle': 'INSPECTOR III, (POLICE DEPARTMENT)',
#    'BasePay': 130457.88,
#    'OvertimePay': 51864.26,
#    'OtherPay': 50380.44,
#    'TotalPay': 232702.58,
#    'TotalPayBenefits': 232702.58,
#    'Year': 2011},
#   {'JobTitle': 'MANAGER VII',
#    'BasePay': 164211.77,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 164211.77,
#    'TotalPayBenefits': 164211.77,
#    'Year': 2011}],
#  'MARK GAMBLE': [{'JobTitle': 'INSPECTOR III, (POLICE DEPARTMENT)',
#    'BasePay': 85578.61,
#    'OvertimePay': 42878.01,
#    'OtherPay': 104030.1,
#    'TotalPay': 232486.72,
#    'TotalPayBenefits': 232486.72,
#    'Year': 2011}],
#  'KEVIN BURKE': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 174872.64,
#    'OvertimePay': 16876.74,
#    'OtherPay': 40258.39,
#    'TotalPay': 232007.77,
#    'TotalPayBenefits': 232007.77,
#    'Year': 2011}],
#  'BERT REYES': [{'JobTitle': 'LIEUTENANT, BUREAU OF FIRE PREVENTION AND PUBLIC S',
#    'BasePay': 73754.05,
#    'OvertimePay': 18679.06,
#    'OtherPay': 139279.69,
#    'TotalPay': 231712.8,
#    'TotalPayBenefits': 231712.8,
#    'Year': 2011}],
#  'MICHAEL DELANE': [{'JobTitle': 'CAPTAIN, FIRE SUPPRESSION',
#    'BasePay': 140546.88,
#    'OvertimePay': 62283.7,
#    'OtherPay': 28821.55,
#    'TotalPay': 231652.13,
#    'TotalPayBenefits': 231652.13,
#    'Year': 2011}],
#  'EDUARDO GONZALEZ': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 168692.62,
#    'OvertimePay': 35096.74,
#    'OtherPay': 27802.89,
#    'TotalPay': 231592.25,
#    'TotalPayBenefits': 231592.25,
#    'Year': 2011}],
#  'YIFANG QIAN': [{'JobTitle': 'SENIOR PHYSICIAN SPECIALIST',
#    'BasePay': 172529.08,
#    'OvertimePay': 0.0,
#    'OtherPay': 58776.96,
#    'TotalPay': 231306.04,
#    'TotalPayBenefits': 231306.04,
#    'Year': 2011}],
#  'ROBERT WINSLOW': [{'JobTitle': 'LIEUTENANT, FIRE DEPARTMENT',
#    'BasePay': 122272.69,
#    'OvertimePay': 90593.53,
#    'OtherPay': 18238.75,
#    'TotalPay': 231104.97,
#    'TotalPayBenefits': 231104.97,
#    'Year': 2011}],
#  'LORRIE KALOS': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 168692.62,
#    'OvertimePay': 41158.72,
#    'OtherPay': 21055.17,
#    'TotalPay': 230906.51,
#    'TotalPayBenefits': 230906.51,
#    'Year': 2011}],
#  'EDWARD REISKIN': [{'JobTitle': 'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#    'BasePay': 230827.12,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 230827.12,
#    'TotalPayBenefits': 230827.12,
#    'Year': 2011}],
#  'JEFFREY MYERS': [{'JobTitle': 'CAPTAIN, EMERGENCYCY MEDICAL SERVICES',
#    'BasePay': 217410.8,
#    'OvertimePay': 0.0,
#    'OtherPay': 13216.41,
#    'TotalPay': 230627.21,
#    'TotalPayBenefits': 230627.21,
#    'Year': 2011}],
#  'JONATHAN BAXTER': [{'JobTitle': 'FIRE FIGHTER PARAMEDIC',
#    'BasePay': 122404.98,
#    'OvertimePay': 92767.41,
#    'OtherPay': 15371.07,
#    'TotalPay': 230543.46,
#    'TotalPayBenefits': 230543.46,
#    'Year': 2011}],
#  'MICHAEL BRYANT': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 150464.82,
#    'OvertimePay': 49813.69,
#    'OtherPay': 30180.49,
#    'TotalPay': 230459.0,
#    'TotalPayBenefits': 230459.0,
#    'Year': 2011}],
#  'KEVIN BARRY': [{'JobTitle': 'MANAGER VII',
#    'BasePay': 96814.36,
#    'OvertimePay': 0.0,
#    'OtherPay': 133563.47,
#    'TotalPay': 230377.83,
#    'TotalPayBenefits': 230377.83,
#    'Year': 2011}],
#  'EVETTE GEER-STEVENS': [{'JobTitle': 'TRANSIT SUPERVISOR',
#    'BasePay': 88062.0,
#    'OvertimePay': 135159.38,
#    'OtherPay': 7018.6,
#    'TotalPay': 230239.98,
#    'TotalPayBenefits': 230239.98,
#    'Year': 2011}],
#  'MARY TSE': [{'JobTitle': 'INSPECTOR, BUREAU OF FIRE PREVENTION AND PUBLIC SA',
#    'BasePay': 138878.82,
#    'OvertimePay': 31843.34,
#    'OtherPay': 59427.12,
#    'TotalPay': 230149.28,
#    'TotalPayBenefits': 230149.28,
#    'Year': 2011}],
#  'MARK GONZALES': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 188842.37,
#    'OvertimePay': 21453.59,
#    'OtherPay': 18764.67,
#    'TotalPay': 229060.63,
#    'TotalPayBenefits': 229060.63,
#    'Year': 2011}],
#  'DONNA MEIXNER': [{'JobTitle': 'CAPTAIN III (POLICE DEPARTMENT)',
#    'BasePay': 102722.4,
#    'OvertimePay': 7437.0,
#    'OtherPay': 118456.21,
#    'TotalPay': 228615.61,
#    'TotalPayBenefits': 228615.61,
#    'Year': 2011}],
#  'PETE FAY JR': [{'JobTitle': 'CAPTAIN, FIRE SUPPRESSION',
#    'BasePay': 149362.84,
#    'OvertimePay': 51847.45,
#    'OtherPay': 27303.11,
#    'TotalPay': 228513.4,
#    'TotalPayBenefits': 228513.4,
#    'Year': 2011}],
#  'JOHN MURPHY': [{'JobTitle': 'CAPTAIN III (POLICE DEPARTMENT)',
#    'BasePay': 215914.03,
#    'OvertimePay': 0.0,
#    'OtherPay': 12293.83,
#    'TotalPay': 228207.86,
#    'TotalPayBenefits': 228207.86,
#    'Year': 2011},
#   {'JobTitle': 'LIEUTENANT, FIRE DEPARTMENT',
#    'BasePay': 123104.98,
#    'OvertimePay': 54870.85,
#    'OtherPay': 15365.22,
#    'TotalPay': 193341.05,
#    'TotalPayBenefits': 193341.05,
#    'Year': 2011},
#   {'JobTitle': 'POLICE OFFICER I',
#    'BasePay': 99960.07,
#    'OvertimePay': 11319.91,
#    'OtherPay': 21963.27,
#    'TotalPay': 133243.25,
#    'TotalPayBenefits': 133243.25,
#    'Year': 2011},
#   {'JobTitle': 'FIREFIGHTER',
#    'BasePay': 58262.43,
#    'OvertimePay': 0.0,
#    'OtherPay': 27250.09,
#    'TotalPay': 85512.52,
#    'TotalPayBenefits': 85512.52,
#    'Year': 2011},
#   {'JobTitle': 'RECREATION LEADER',
#    'BasePay': 6709.62,
#    'OvertimePay': 0.0,
#    'OtherPay': 39.0,
#    'TotalPay': 6748.62,
#    'TotalPayBenefits': 6748.62,
#    'Year': 2011}],
#  'REX HALE': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 168692.62,
#    'OvertimePay': 33191.6,
#    'OtherPay': 25434.68,
#    'TotalPay': 227318.9,
#    'TotalPayBenefits': 227318.9,
#    'Year': 2011}],
#  'MIVIC HIROSE': [{'JobTitle': 'MANAGER VIII',
#    'BasePay': 215180.76,
#    'OvertimePay': 0.0,
#    'OtherPay': 12000.0,
#    'TotalPay': 227180.76,
#    'TotalPayBenefits': 227180.76,
#    'Year': 2011}],
#  'SARAH CARY': [{'JobTitle': 'ANESTHETIST',
#    'BasePay': 208925.6,
#    'OvertimePay': 5539.3,
#    'OtherPay': 12615.6,
#    'TotalPay': 227080.5,
#    'TotalPayBenefits': 227080.5,
#    'Year': 2011}],
#  'KEVIN SMITH': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 168692.67,
#    'OvertimePay': 35402.71,
#    'OtherPay': 22261.95,
#    'TotalPay': 226357.33,
#    'TotalPayBenefits': 226357.33,
#    'Year': 2011},
#   {'JobTitle': 'HEALTH WORKER III',
#    'BasePay': 46334.22,
#    'OvertimePay': 0.0,
#    'OtherPay': 1200.65,
#    'TotalPay': 47534.87,
#    'TotalPayBenefits': 47534.87,
#    'Year': 2011},
#   {'JobTitle': 'TRANSIT OPERATOR',
#    'BasePay': 37498.71,
#    'OvertimePay': 4381.06,
#    'OtherPay': 571.77,
#    'TotalPay': 42451.54,
#    'TotalPayBenefits': 42451.54,
#    'Year': 2011},
#   {'JobTitle': 'PORTER',
#    'BasePay': 17911.05,
#    'OvertimePay': 0.0,
#    'OtherPay': 283.69,
#    'TotalPay': 18194.74,
#    'TotalPayBenefits': 18194.74,
#    'Year': 2011},
#   {'JobTitle': 'PUBLIC SERVICE TRAINEE',
#    'BasePay': 6121.5,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 6121.5,
#    'TotalPayBenefits': 6121.5,
#    'Year': 2011}],
#  'GREGORY STANGLAND': [{'JobTitle': 'FIRE FIGHTER PARAMEDIC',
#    'BasePay': 122404.98,
#    'OvertimePay': 86719.38,
#    'OtherPay': 15315.61,
#    'TotalPay': 224439.97,
#    'TotalPayBenefits': 224439.97,
#    'Year': 2011}],
#  'SONALI BOSE': [{'JobTitle': 'DEPUTY DIRECTOR II - MUNICIPAL TRANSPORTATION AG',
#    'BasePay': 224035.85,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 224035.85,
#    'TotalPayBenefits': 224035.85,
#    'Year': 2011}],
#  'KEVIN TAYLOR': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 168692.65,
#    'OvertimePay': 33656.87,
#    'OtherPay': 21502.83,
#    'TotalPay': 223852.35,
#    'TotalPayBenefits': 223852.35,
#    'Year': 2011}],
#  'ERIKA HOO': [{'JobTitle': 'LIEUTENANT, FIRE DEPARTMENT',
#    'BasePay': 123105.0,
#    'OvertimePay': 84547.16,
#    'OtherPay': 16054.24,
#    'TotalPay': 223706.4,
#    'TotalPayBenefits': 223706.4,
#    'Year': 2011}],
#  'LAUIFI SEUMAALA': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 105934.69,
#    'OvertimePay': 98534.35,
#    'OtherPay': 18890.96,
#    'TotalPay': 223360.0,
#    'TotalPayBenefits': 223360.0,
#    'Year': 2011}],
#  'EDWARD DENNIS': [{'JobTitle': 'TRANSIT SUPERVISOR',
#    'BasePay': 88400.7,
#    'OvertimePay': 126778.88,
#    'OtherPay': 7228.67,
#    'TotalPay': 222408.25,
#    'TotalPayBenefits': 222408.25,
#    'Year': 2011}],
#  'PATRIC STEELE': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 105934.64,
#    'OvertimePay': 97395.59,
#    'OtherPay': 18760.77,
#    'TotalPay': 222091.0,
#    'TotalPayBenefits': 222091.0,
#    'Year': 2011}],
#  'MICHAEL WALSH': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 110474.93,
#    'OvertimePay': 83670.04,
#    'OtherPay': 27043.61,
#    'TotalPay': 221188.58,
#    'TotalPayBenefits': 221188.58,
#    'Year': 2011},
#   {'JobTitle': 'POLICE OFFICER III',
#    'BasePay': 112421.45,
#    'OvertimePay': 8054.43,
#    'OtherPay': 33553.12,
#    'TotalPay': 154029.0,
#    'TotalPayBenefits': 154029.0,
#    'Year': 2011},
#   {'JobTitle': 'SENIOR ACCOUNT CLERK',
#    'BasePay': 49705.04,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 49705.04,
#    'TotalPayBenefits': 49705.04,
#    'Year': 2011}],
#  'SAMSON LAI': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 149362.86,
#    'OvertimePay': 35003.5,
#    'OtherPay': 36682.96,
#    'TotalPay': 221049.32,
#    'TotalPayBenefits': 221049.32,
#    'Year': 2011}],
#  'GLORIA GARCIA ORME': [{'JobTitle': 'NURSING SUPERVISOR',
#    'BasePay': 188708.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 32080.36,
#    'TotalPay': 220788.36,
#    'TotalPayBenefits': 220788.36,
#    'Year': 2011}],
#  'ANA SAMPERA': [{'JobTitle': 'NURSING SUPERVISOR',
#    'BasePay': 188708.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 32080.36,
#    'TotalPay': 220788.36,
#    'TotalPayBenefits': 220788.36,
#    'Year': 2011},
#   {'JobTitle': 'NURSING SUPERVISOR',
#    'BasePay': 5443.49,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 5443.49,
#    'TotalPayBenefits': 5443.49,
#    'Year': 2011}],
#  'SCOTT SCHOLZEN': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 105934.67,
#    'OvertimePay': 96154.33,
#    'OtherPay': 18655.85,
#    'TotalPay': 220744.85,
#    'TotalPayBenefits': 220744.85,
#    'Year': 2011}],
#  'MARK SMITH': [{'JobTitle': 'ANESTHETIST',
#    'BasePay': 206057.69,
#    'OvertimePay': 3431.01,
#    'OtherPay': 10921.33,
#    'TotalPay': 220410.03,
#    'TotalPayBenefits': 220410.03,
#    'Year': 2011}],
#  'C PETRUZZELLA': [{'JobTitle': 'POLICE OFFICER III',
#    'BasePay': 63811.18,
#    'OvertimePay': 57966.33,
#    'OtherPay': 98578.97,
#    'TotalPay': 220356.48,
#    'TotalPayBenefits': 220356.48,
#    'Year': 2011}],
#  'JOHN HALEY JR': [{'JobTitle': 'DEPUTY DIRECTOR II - MUNICIPAL TRANSPORTATION AG',
#    'BasePay': 220115.22,
#    'OvertimePay': 0.0,
#    'OtherPay': 237.0,
#    'TotalPay': 220352.22,
#    'TotalPayBenefits': 220352.22,
#    'Year': 2011}],
#  'NELA PONFERRADA': [{'JobTitle': 'NURSING SUPERVISOR',
#    'BasePay': 188708.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 31572.3,
#    'TotalPay': 220280.3,
#    'TotalPayBenefits': 220280.3,
#    'Year': 2011},
#   {'JobTitle': 'NURSING SUPERVISOR',
#    'BasePay': 20685.3,
#    'OvertimePay': 0.0,
#    'OtherPay': 2068.53,
#    'TotalPay': 22753.83,
#    'TotalPayBenefits': 22753.83,
#    'Year': 2011}],
#  'CHARLES SCOTT': [{'JobTitle': 'TRANSIT SUPERVISOR',
#    'BasePay': 88400.7,
#    'OvertimePay': 119951.72,
#    'OtherPay': 11893.84,
#    'TotalPay': 220246.26,
#    'TotalPayBenefits': 220246.26,
#    'Year': 2011}],
#  'LISETTE ADAMS': [{'JobTitle': "SHERIFF'S LIEUTENANT",
#    'BasePay': 121628.34,
#    'OvertimePay': 89920.21,
#    'OtherPay': 8383.77,
#    'TotalPay': 219932.32,
#    'TotalPayBenefits': 219932.32,
#    'Year': 2011}],
#  'JACKSON WONG': [{'JobTitle': 'DEPUTY DIRECTOR V',
#    'BasePay': 219804.34,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 219804.34,
#    'TotalPayBenefits': 219804.34,
#    'Year': 2011}],
#  'IRENE SUNG': [{'JobTitle': 'SUPERVISING PHYSICIAN SPECIALIST',
#    'BasePay': 191054.19,
#    'OvertimePay': 0.0,
#    'OtherPay': 28658.16,
#    'TotalPay': 219712.35,
#    'TotalPayBenefits': 219712.35,
#    'Year': 2011}],
#  'KHAIRUL ALI': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 150432.85,
#    'OvertimePay': 42365.89,
#    'OtherPay': 25995.01,
#    'TotalPay': 218793.75,
#    'TotalPayBenefits': 218793.75,
#    'Year': 2011}],
#  'LESLIE DUBBIN': [{'JobTitle': 'NURSING SUPERVISOR',
#    'BasePay': 179648.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 39029.76,
#    'TotalPay': 218677.76,
#    'TotalPayBenefits': 218677.76,
#    'Year': 2011},
#   {'JobTitle': 'NURSING SUPERVISOR',
#    'BasePay': 31935.2,
#    'OvertimePay': 0.0,
#    'OtherPay': 3338.68,
#    'TotalPay': 35273.88,
#    'TotalPayBenefits': 35273.88,
#    'Year': 2011}],
#  'MICHAEL CASTAGNOLA': [{'JobTitle': 'CAPTAIN, FIRE SUPPRESSION',
#    'BasePay': 140546.88,
#    'OvertimePay': 52095.06,
#    'OtherPay': 25564.1,
#    'TotalPay': 218206.04,
#    'TotalPayBenefits': 218206.04,
#    'Year': 2011}],
#  'SHELLEY MITCHELL': [{'JobTitle': 'ANESTHETIST',
#    'BasePay': 203658.55,
#    'OvertimePay': 4759.36,
#    'OtherPay': 9561.44,
#    'TotalPay': 217979.35,
#    'TotalPayBenefits': 217979.35,
#    'Year': 2011},
#   {'JobTitle': 'CHILD SUPPORT OFFICER II',
#    'BasePay': 65859.44,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 65859.44,
#    'TotalPayBenefits': 65859.44,
#    'Year': 2011}],
#  'SEAN BONETTI': [{'JobTitle': 'FIRE FIGHTER PARAMEDIC',
#    'BasePay': 122594.0,
#    'OvertimePay': 79721.87,
#    'OtherPay': 15646.15,
#    'TotalPay': 217962.02,
#    'TotalPayBenefits': 217962.02,
#    'Year': 2011}],
#  'SUSAN ILNICKI': [{'JobTitle': 'NURSING SUPERVISOR',
#    'BasePay': 188889.44,
#    'OvertimePay': 0.0,
#    'OtherPay': 28921.31,
#    'TotalPay': 217810.75,
#    'TotalPayBenefits': 217810.75,
#    'Year': 2011},
#   {'JobTitle': 'NURSING SUPERVISOR',
#    'BasePay': 9798.3,
#    'OvertimePay': 0.0,
#    'OtherPay': 3048.36,
#    'TotalPay': 12846.66,
#    'TotalPayBenefits': 12846.66,
#    'Year': 2011}],
#  'TYRONNE JULIAN': [{'JobTitle': 'TRANSIT SUPERVISOR',
#    'BasePay': 88062.0,
#    'OvertimePay': 126725.82,
#    'OtherPay': 2784.61,
#    'TotalPay': 217572.43,
#    'TotalPayBenefits': 217572.43,
#    'Year': 2011}],
#  'SHARON FERRIGNO': [{'JobTitle': 'CAPTAIN III (POLICE DEPARTMENT)',
#    'BasePay': 185369.68,
#    'OvertimePay': 27321.83,
#    'OtherPay': 4651.44,
#    'TotalPay': 217342.95,
#    'TotalPayBenefits': 217342.95,
#    'Year': 2011}],
#  'SHANNON SAKOWSKI': [{'JobTitle': 'ANESTHETIST',
#    'BasePay': 192170.93,
#    'OvertimePay': 11260.27,
#    'OtherPay': 13712.8,
#    'TotalPay': 217144.0,
#    'TotalPayBenefits': 217144.0,
#    'Year': 2011}],
#  'JOHN HICKEY': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 168692.63,
#    'OvertimePay': 22432.91,
#    'OtherPay': 25855.73,
#    'TotalPay': 216981.27,
#    'TotalPayBenefits': 216981.27,
#    'Year': 2011}],
#  'GLEN KOJIMOTO': [{'JobTitle': 'CAPTAIN, FIRE SUPPRESSION',
#    'BasePay': 140546.85,
#    'OvertimePay': 58354.29,
#    'OtherPay': 17823.03,
#    'TotalPay': 216724.17,
#    'TotalPayBenefits': 216724.17,
#    'Year': 2011}],
#  'EDWARD CHU': [{'JobTitle': 'LIEUTENANT, FIRE DEPARTMENT',
#    'BasePay': 123105.0,
#    'OvertimePay': 77259.53,
#    'OtherPay': 16054.2,
#    'TotalPay': 216418.73,
#    'TotalPayBenefits': 216418.73,
#    'Year': 2011}],
#  'SOFIA MATHEWS': [{'JobTitle': 'LIEUTENANT, BUREAU OF FIRE PREVENTION AND PUBLIC S',
#    'BasePay': 158603.68,
#    'OvertimePay': 0.0,
#    'OtherPay': 57667.12,
#    'TotalPay': 216270.8,
#    'TotalPayBenefits': 216270.8,
#    'Year': 2011}],
#  'EDMUND DEA': [{'JobTitle': 'CAPTAIN, FIRE SUPPRESSION',
#    'BasePay': 141648.87,
#    'OvertimePay': 43574.57,
#    'OtherPay': 30952.65,
#    'TotalPay': 216176.09,
#    'TotalPayBenefits': 216176.09,
#    'Year': 2011}],
#  'JOHN RAHAIM': [{'JobTitle': 'DEPARTMENT HEAD IV',
#    'BasePay': 215799.48,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 215799.48,
#    'TotalPayBenefits': 215799.48,
#    'Year': 2011}],
#  'WILLIAM ROUALDES': [{'JobTitle': 'LIEUTENANT III (POLICE DEPARTMENT)',
#    'BasePay': 149044.93,
#    'OvertimePay': 4836.87,
#    'OtherPay': 61531.43,
#    'TotalPay': 215413.23,
#    'TotalPayBenefits': 215413.23,
#    'Year': 2011}],
#  'ZACHARY PUMPHREY': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 166203.84,
#    'OvertimePay': 28448.6,
#    'OtherPay': 20744.06,
#    'TotalPay': 215396.5,
#    'TotalPayBenefits': 215396.5,
#    'Year': 2011}],
#  'MARK CASTAGNOLA': [{'JobTitle': 'LIEUTENANT, FIRE DEPARTMENT',
#    'BasePay': 123416.25,
#    'OvertimePay': 66447.73,
#    'OtherPay': 25491.13,
#    'TotalPay': 215355.11,
#    'TotalPayBenefits': 215355.11,
#    'Year': 2011}],
#  'NIKOLAS LEMOS': [{'JobTitle': 'FORENSIC TOXICOLOGIST',
#    'BasePay': 182368.79,
#    'OvertimePay': 0.0,
#    'OtherPay': 32949.41,
#    'TotalPay': 215318.2,
#    'TotalPayBenefits': 215318.2,
#    'Year': 2011}],
#  'MICHAEL CARLIN': [{'JobTitle': 'DEPUTY DIRECTOR V',
#    'BasePay': 215180.75,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 215180.75,
#    'TotalPayBenefits': 215180.75,
#    'Year': 2011}],
#  'MARISA MORET': [{'JobTitle': 'CONFIDENTIAL CHIEF ATTORNEY II (CIVIL & CRIMINAL)',
#    'BasePay': 213907.72,
#    'OvertimePay': 0.0,
#    'OtherPay': 1080.96,
#    'TotalPay': 214988.68,
#    'TotalPayBenefits': 214988.68,
#    'Year': 2011}],
#  'JESSE SMITH': [{'JobTitle': 'CONFIDENTIAL CHIEF ATTORNEY II (CIVIL & CRIMINAL)',
#    'BasePay': 213907.72,
#    'OvertimePay': 0.0,
#    'OtherPay': 1080.96,
#    'TotalPay': 214988.68,
#    'TotalPayBenefits': 214988.68,
#    'Year': 2011}],
#  'THERESE STEWART': [{'JobTitle': 'CONFIDENTIAL CHIEF ATTORNEY II (CIVIL & CRIMINAL)',
#    'BasePay': 213907.72,
#    'OvertimePay': 0.0,
#    'OtherPay': 1080.96,
#    'TotalPay': 214988.68,
#    'TotalPayBenefits': 214988.68,
#    'Year': 2011}],
#  'LUIS IBARRA-RIVERA': [{'JobTitle': 'LIEUTENANT, FIRE DEPARTMENT',
#    'BasePay': 123105.0,
#    'OvertimePay': 74266.87,
#    'OtherPay': 17583.73,
#    'TotalPay': 214955.6,
#    'TotalPayBenefits': 214955.6,
#    'Year': 2011}],
#  'GERALD DARCY': [{'JobTitle': 'SERGEANT III (POLICE DEPARTMENT)',
#    'BasePay': 130481.53,
#    'OvertimePay': 2433.29,
#    'OtherPay': 82029.92,
#    'TotalPay': 214944.74,
#    'TotalPayBenefits': 214944.74,
#    'Year': 2011}],
#  'DONNIE HORNBUCKLE': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 105934.63,
#    'OvertimePay': 96611.56,
#    'OtherPay': 12306.26,
#    'TotalPay': 214852.45,
#    'TotalPayBenefits': 214852.45,
#    'Year': 2011}],
#  'SANDRA TONG': [{'JobTitle': 'COMMANDER III, (POLICE DEPARTMENT)',
#    'BasePay': 206438.88,
#    'OvertimePay': 0.0,
#    'OtherPay': 8377.03,
#    'TotalPay': 214815.91,
#    'TotalPayBenefits': 214815.91,
#    'Year': 2011},
#   {'JobTitle': 'CAPTAIN, EMERGENCYCY MEDICAL SERVICES',
#    'BasePay': 140546.88,
#    'OvertimePay': 20407.79,
#    'OtherPay': 13637.71,
#    'TotalPay': 174592.38,
#    'TotalPayBenefits': 174592.38,
#    'Year': 2011}],
#  'ANTHONY DUMONT': [{'JobTitle': 'CAPTAIN, EMERGENCYCY MEDICAL SERVICES',
#    'BasePay': 140546.63,
#    'OvertimePay': 53209.03,
#    'OtherPay': 20429.43,
#    'TotalPay': 214185.09,
#    'TotalPayBenefits': 214185.09,
#    'Year': 2011}],
#  'THERESA DENTONI': [{'JobTitle': 'NURSING SUPERVISOR',
#    'BasePay': 183040.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 31116.8,
#    'TotalPay': 214156.8,
#    'TotalPayBenefits': 214156.8,
#    'Year': 2011},
#   {'JobTitle': 'NURSING SUPERVISOR',
#    'BasePay': 22499.8,
#    'OvertimePay': 0.0,
#    'OtherPay': 2177.4,
#    'TotalPay': 24677.2,
#    'TotalPayBenefits': 24677.2,
#    'Year': 2011}],
#  'TIM AREJA': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 105934.69,
#    'OvertimePay': 90329.62,
#    'OtherPay': 17596.3,
#    'TotalPay': 213860.61,
#    'TotalPayBenefits': 213860.61,
#    'Year': 2011}],
#  'SIU-KWAN CHOW': [{'JobTitle': 'SENIOR PHYSICIAN SPECIALIST',
#    'BasePay': 167070.08,
#    'OvertimePay': 0.0,
#    'OtherPay': 46665.54,
#    'TotalPay': 213735.62,
#    'TotalPayBenefits': 213735.62,
#    'Year': 2011}],
#  'PATRICIA CARR': [{'JobTitle': 'NURSING SUPERVISOR',
#    'BasePay': 183040.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 30619.46,
#    'TotalPay': 213659.46,
#    'TotalPayBenefits': 213659.46,
#    'Year': 2011},
#   {'JobTitle': 'NURSING SUPERVISOR',
#    'BasePay': 2631.02,
#    'OvertimePay': 0.0,
#    'OtherPay': 771.16,
#    'TotalPay': 3402.18,
#    'TotalPayBenefits': 3402.18,
#    'Year': 2011}],
#  'RASMI CHAN': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 105934.64,
#    'OvertimePay': 89485.44,
#    'OtherPay': 18117.8,
#    'TotalPay': 213537.88,
#    'TotalPayBenefits': 213537.88,
#    'Year': 2011}],
#  'MICHAEL KEARNEY': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 181502.08,
#    'OvertimePay': 0.0,
#    'OtherPay': 31449.4,
#    'TotalPay': 212951.48,
#    'TotalPayBenefits': 212951.48,
#    'Year': 2011}],
#  'MATTHEW MCNAUGHTON': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 173842.63,
#    'OvertimePay': 1210.13,
#    'OtherPay': 37804.9,
#    'TotalPay': 212857.66,
#    'TotalPayBenefits': 212857.66,
#    'Year': 2011}],
#  'JOHN CAVANAUGH': [{'JobTitle': 'CAPTAIN, EMERGENCYCY MEDICAL SERVICES',
#    'BasePay': 140546.88,
#    'OvertimePay': 54054.41,
#    'OtherPay': 18236.44,
#    'TotalPay': 212837.73,
#    'TotalPayBenefits': 212837.73,
#    'Year': 2011}],
#  'WHITNEY YEE': [{'JobTitle': 'DEPUTY SHERIFF',
#    'BasePay': 86840.0,
#    'OvertimePay': 112320.96,
#    'OtherPay': 13544.56,
#    'TotalPay': 212705.52,
#    'TotalPayBenefits': 212705.52,
#    'Year': 2011}],
#  'STEVEN MANNINA': [{'JobTitle': 'LIEUTENANT III (POLICE DEPARTMENT)',
#    'BasePay': 149050.69,
#    'OvertimePay': 57364.23,
#    'OtherPay': 6235.28,
#    'TotalPay': 212650.2,
#    'TotalPayBenefits': 212650.2,
#    'Year': 2011}],
#  'EDGAR CALLEJAS': [{'JobTitle': 'SERGEANT III (POLICE DEPARTMENT)',
#    'BasePay': 82235.56,
#    'OvertimePay': 43352.6,
#    'OtherPay': 86590.93,
#    'TotalPay': 212179.09,
#    'TotalPayBenefits': 212179.09,
#    'Year': 2011}],
#  'L MILITELLO': [{'JobTitle': 'COMMANDER III, (POLICE DEPARTMENT)',
#    'BasePay': 182134.81,
#    'OvertimePay': 18574.4,
#    'OtherPay': 11000.84,
#    'TotalPay': 211710.05,
#    'TotalPayBenefits': 211710.05,
#    'Year': 2011}],
#  'MICHAEL BIEL': [{'JobTitle': 'COMMANDER III, (POLICE DEPARTMENT)',
#    'BasePay': 198778.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 12818.24,
#    'TotalPay': 211596.24,
#    'TotalPayBenefits': 211596.24,
#    'Year': 2011}],
#  'DEBRA JOHNSON': [{'JobTitle': 'DEPUTY DIRECTOR II - MUNICIPAL TRANSPORTATION AG',
#    'BasePay': 210821.61,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 210821.61,
#    'TotalPayBenefits': 210821.61,
#    'Year': 2011}],
#  'HAROLD BYRD': [{'JobTitle': 'TRANSIT SUPERVISOR',
#    'BasePay': 88062.0,
#    'OvertimePay': 111199.78,
#    'OtherPay': 11373.58,
#    'TotalPay': 210635.36,
#    'TotalPayBenefits': 210635.36,
#    'Year': 2011}],
#  'KARL JURGENSON': [{'JobTitle': 'FIRE FIGHTER PARAMEDIC',
#    'BasePay': 122404.98,
#    'OvertimePay': 72836.43,
#    'OtherPay': 15336.91,
#    'TotalPay': 210578.32,
#    'TotalPayBenefits': 210578.32,
#    'Year': 2011}],
#  'JULIE LABONTE': [{'JobTitle': 'MANAGER VIII',
#    'BasePay': 207501.2,
#    'OvertimePay': 0.0,
#    'OtherPay': 2903.37,
#    'TotalPay': 210404.57,
#    'TotalPayBenefits': 210404.57,
#    'Year': 2011}],
#  'JOHN BRAGAGNOLO': [{'JobTitle': 'SERGEANT III (POLICE DEPARTMENT)',
#    'BasePay': 130457.96,
#    'OvertimePay': 6284.61,
#    'OtherPay': 73334.31,
#    'TotalPay': 210076.88,
#    'TotalPayBenefits': 210076.88,
#    'Year': 2011}],
#  'OSCAR CABRERA': [{'JobTitle': 'FIRE FIGHTER PARAMEDIC',
#    'BasePay': 116603.33,
#    'OvertimePay': 78532.26,
#    'OtherPay': 14753.88,
#    'TotalPay': 209889.47,
#    'TotalPayBenefits': 209889.47,
#    'Year': 2011}],
#  'MARTIEN VERHAEG': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 105934.67,
#    'OvertimePay': 87642.33,
#    'OtherPay': 16228.64,
#    'TotalPay': 209805.64,
#    'TotalPayBenefits': 209805.64,
#    'Year': 2011}],
#  'THOMAS ALDANA': [{'JobTitle': 'TRANSIT SUPERVISOR',
#    'BasePay': 90094.2,
#    'OvertimePay': 111323.49,
#    'OtherPay': 8344.75,
#    'TotalPay': 209762.44,
#    'TotalPayBenefits': 209762.44,
#    'Year': 2011}],
#  'CARL JEPSEN': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 105934.65,
#    'OvertimePay': 89773.95,
#    'OtherPay': 14007.96,
#    'TotalPay': 209716.56,
#    'TotalPayBenefits': 209716.56,
#    'Year': 2011}],
#  'AMPARO RODRIGUEZ': [{'JobTitle': 'NURSE MANAGER',
#    'BasePay': 161044.0,
#    'OvertimePay': 4599.05,
#    'OtherPay': 43997.82,
#    'TotalPay': 209640.87,
#    'TotalPayBenefits': 209640.87,
#    'Year': 2011},
#   {'JobTitle': 'NURSING SUPERVISOR',
#    'BasePay': 20540.13,
#    'OvertimePay': 0.0,
#    'OtherPay': 2404.22,
#    'TotalPay': 22944.35,
#    'TotalPayBenefits': 22944.35,
#    'Year': 2011}],
#  'WILLIAM SCOTT': [{'JobTitle': 'INSPECTOR III, (POLICE DEPARTMENT)',
#    'BasePay': 130481.56,
#    'OvertimePay': 45597.19,
#    'OtherPay': 33307.68,
#    'TotalPay': 209386.43,
#    'TotalPayBenefits': 209386.43,
#    'Year': 2011}],
#  'GEORGE LYSENKO': [{'JobTitle': 'LIEUTENANT, FIRE DEPARTMENT',
#    'BasePay': 123105.02,
#    'OvertimePay': 67899.46,
#    'OtherPay': 18300.05,
#    'TotalPay': 209304.53,
#    'TotalPayBenefits': 209304.53,
#    'Year': 2011}],
#  'MICHAEL BROWNE': [{'JobTitle': 'SERGEANT III (POLICE DEPARTMENT)',
#    'BasePay': 130457.88,
#    'OvertimePay': 47342.41,
#    'OtherPay': 31413.52,
#    'TotalPay': 209213.81,
#    'TotalPayBenefits': 209213.81,
#    'Year': 2011}],
#  'HARRY PINKARD': [{'JobTitle': 'CAPTAIN, FIRE SUPPRESSION',
#    'BasePay': 60373.82,
#    'OvertimePay': 25046.44,
#    'OtherPay': 123649.73,
#    'TotalPay': 209069.99,
#    'TotalPayBenefits': 209069.99,
#    'Year': 2011}],
#  'ALBERTO PEDRUCO': [{'JobTitle': 'LIEUTENANT, FIRE DEPARTMENT',
#    'BasePay': 135651.04,
#    'OvertimePay': 56307.38,
#    'OtherPay': 17085.77,
#    'TotalPay': 209044.19,
#    'TotalPayBenefits': 209044.19,
#    'Year': 2011}],
#  'LAWRENCE LEE': [{'JobTitle': 'ELECTRICAL TRANSIT SYSTEM MECHANIC',
#    'BasePay': 77580.4,
#    'OvertimePay': 115239.98,
#    'OtherPay': 16089.38,
#    'TotalPay': 208909.76,
#    'TotalPayBenefits': 208909.76,
#    'Year': 2011},
#   {'JobTitle': 'COMMISSIONER',
#    'BasePay': 6570.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 6570.0,
#    'TotalPayBenefits': 6570.0,
#    'Year': 2011}],
#  'DWAYNE CURRY': [{'JobTitle': 'LIEUTENANT, FIRE DEPARTMENT',
#    'BasePay': 133769.86,
#    'OvertimePay': 56093.64,
#    'OtherPay': 18879.06,
#    'TotalPay': 208742.56,
#    'TotalPayBenefits': 208742.56,
#    'Year': 2011}],
#  'RENEE MARQUARDT': [{'JobTitle': 'SENIOR PHYSICIAN SPECIALIST',
#    'BasePay': 175345.85,
#    'OvertimePay': 0.0,
#    'OtherPay': 33357.87,
#    'TotalPay': 208703.72,
#    'TotalPayBenefits': 208703.72,
#    'Year': 2011}],
#  'HARVEY ELWIN': [{'JobTitle': 'MANAGER VIII',
#    'BasePay': 200385.64,
#    'OvertimePay': 0.0,
#    'OtherPay': 8000.0,
#    'TotalPay': 208385.64,
#    'TotalPayBenefits': 208385.64,
#    'Year': 2011}],
#  'LEON WHITE': [{'JobTitle': 'FIRE FIGHTER PARAMEDIC',
#    'BasePay': 122405.0,
#    'OvertimePay': 68861.18,
#    'OtherPay': 17071.3,
#    'TotalPay': 208337.48,
#    'TotalPayBenefits': 208337.48,
#    'Year': 2011}],
#  'DENNIS HERRERA': [{'JobTitle': 'CITY ATTORNEY',
#    'BasePay': 208243.12,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 208243.12,
#    'TotalPayBenefits': 208243.12,
#    'Year': 2011}],
#  'DONALD BRYANT': [{'JobTitle': 'ELECTRICAL TRANSIT SYSTEM MECHANIC',
#    'BasePay': 77580.36,
#    'OvertimePay': 119407.7,
#    'OtherPay': 11220.57,
#    'TotalPay': 208208.63,
#    'TotalPayBenefits': 208208.63,
#    'Year': 2011}],
#  'NATHAN HARDY': [{'JobTitle': 'MARINE ENGINEER OF FIRE BOATS',
#    'BasePay': 140546.85,
#    'OvertimePay': 47122.83,
#    'OtherPay': 20353.22,
#    'TotalPay': 208022.9,
#    'TotalPayBenefits': 208022.9,
#    'Year': 2011}],
#  'SUSAN BUCHBINDER': [{'JobTitle': 'MANAGER VIII',
#    'BasePay': 207874.94,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 207874.94,
#    'TotalPayBenefits': 207874.94,
#    'Year': 2011}],
#  'KIRSTEN BARASH': [{'JobTitle': 'ANESTHETIST',
#    'BasePay': 189853.68,
#    'OvertimePay': 7060.31,
#    'OtherPay': 10941.53,
#    'TotalPay': 207855.52,
#    'TotalPayBenefits': 207855.52,
#    'Year': 2011}],
#  'DENNIS SUTTER': [{'JobTitle': 'BATTALION CHIEF, (FIRE DEPARTMENT)',
#    'BasePay': 63878.03,
#    'OvertimePay': 24586.55,
#    'OtherPay': 119351.05,
#    'TotalPay': 207815.63,
#    'TotalPayBenefits': 207815.63,
#    'Year': 2011}],
#  'JOHN BROWN': [{'JobTitle': 'MANAGER VIII',
#    'BasePay': 207798.79,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 207798.79,
#    'TotalPayBenefits': 207798.79,
#    'Year': 2011}],
#  'KATHRYN BALLOU': [{'JobTitle': 'NURSING SUPERVISOR PSYCHIATRIC',
#    'BasePay': 177528.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 30179.76,
#    'TotalPay': 207707.76,
#    'TotalPayBenefits': 207707.76,
#    'Year': 2011}],
#  'DONALD FIELDS': [{'JobTitle': 'LIEUTENANT, BUREAU OF FIRE PREVENTION AND PUBLIC S',
#    'BasePay': 158603.6,
#    'OvertimePay': 2605.95,
#    'OtherPay': 46493.65,
#    'TotalPay': 207703.2,
#    'TotalPayBenefits': 207703.2,
#    'Year': 2011}],
#  'LUIS HERRERA': [{'JobTitle': 'DEPARTMENT HEAD IV',
#    'BasePay': 207699.73,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 207699.73,
#    'TotalPayBenefits': 207699.73,
#    'Year': 2011}],
#  'GEORGE FOURAS': [{'JobTitle': 'SENIOR PHYSICIAN SPECIALIST',
#    'BasePay': 173937.49,
#    'OvertimePay': 0.0,
#    'OtherPay': 33362.65,
#    'TotalPay': 207300.14,
#    'TotalPayBenefits': 207300.14,
#    'Year': 2011}],
#  'MARTIN LALOR JR': [{'JobTitle': 'SERGEANT III (POLICE DEPARTMENT)',
#    'BasePay': 130434.29,
#    'OvertimePay': 47465.62,
#    'OtherPay': 29377.94,
#    'TotalPay': 207277.85,
#    'TotalPayBenefits': 207277.85,
#    'Year': 2011}],
#  'GRAD GREEN': [{'JobTitle': 'NURSING SUPERVISOR PSYCHIATRIC',
#    'BasePay': 178526.48,
#    'OvertimePay': 0.0,
#    'OtherPay': 28694.26,
#    'TotalPay': 207220.74,
#    'TotalPayBenefits': 207220.74,
#    'Year': 2011}],
#  'DARCY KELLER': [{'JobTitle': 'INSPECTOR III, (POLICE DEPARTMENT)',
#    'BasePay': 130457.96,
#    'OvertimePay': 43329.66,
#    'OtherPay': 33299.41,
#    'TotalPay': 207087.03,
#    'TotalPayBenefits': 207087.03,
#    'Year': 2011}],
#  'SAMUEL ROMERO': [{'JobTitle': 'CAPTAIN, FIRE SUPPRESSION',
#    'BasePay': 140546.87,
# ...
#    'TotalPay': 171713.01,
#    'TotalPayBenefits': 171713.01,
#    'Year': 2011}],
#  'JOHN GLISCHINSKI': [{'JobTitle': 'SERGEANT III (POLICE DEPARTMENT)',
#    'BasePay': 130457.94,
#    'OvertimePay': 16818.84,
#    'OtherPay': 24409.25,
#    'TotalPay': 171686.03,
#    'TotalPayBenefits': 171686.03,
#    'Year': 2011}],
#  'BOAZ MARILES': [{'JobTitle': 'POLICE OFFICER III',
#    'BasePay': 112441.8,
#    'OvertimePay': 16649.8,
#    'OtherPay': 42571.98,
#    'TotalPay': 171663.58,
#    'TotalPayBenefits': 171663.58,
#    'Year': 2011}],
#  'PREM SINGH': [{'JobTitle': 'TRANSIT SUPERVISOR',
#    'BasePay': 86019.1,
#    'OvertimePay': 74599.57,
#    'OtherPay': 10950.14,
#    'TotalPay': 171568.81,
#    'TotalPayBenefits': 171568.81,
#    'Year': 2011}],
#  'AMALIA FYLES': [{'JobTitle': 'CLINICAL NURSE SPECIALIST',
#    'BasePay': 169572.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 1994.81,
#    'TotalPay': 171566.81,
#    'TotalPayBenefits': 171566.81,
#    'Year': 2011}],
#  'RONALD FLYNN': [{'JobTitle': 'HEAD ATTORNEY, CIVIL AND CRIMINAL',
#    'BasePay': 171566.28,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 171566.28,
#    'TotalPayBenefits': 171566.28,
#    'Year': 2011}],
#  'JAMES KIMBALL': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 105934.65,
#    'OvertimePay': 43670.28,
#    'OtherPay': 21936.69,
#    'TotalPay': 171541.62,
#    'TotalPayBenefits': 171541.62,
#    'Year': 2011}],
#  'CHRISTOPHER MADSEN': [{'JobTitle': 'LIEUTENANT, FIRE DEPARTMENT',
#    'BasePay': 127681.16,
#    'OvertimePay': 26427.84,
#    'OtherPay': 17387.25,
#    'TotalPay': 171496.25,
#    'TotalPayBenefits': 171496.25,
#    'Year': 2011}],
#  'MICHAEL STASKO': [{'JobTitle': 'LIEUTENANT III (POLICE DEPARTMENT)',
#    'BasePay': 149050.49,
#    'OvertimePay': 8600.22,
#    'OtherPay': 13812.98,
#    'TotalPay': 171463.69,
#    'TotalPayBenefits': 171463.69,
#    'Year': 2011}],
#  'CLINTON BUNKER': [{'JobTitle': 'ANESTHETIST',
#    'BasePay': 163240.28,
#    'OvertimePay': 1143.54,
#    'OtherPay': 7065.24,
#    'TotalPay': 171449.06,
#    'TotalPayBenefits': 171449.06,
#    'Year': 2011}],
#  'KEVIN DEMPSEY': [{'JobTitle': 'SERGEANT III (POLICE DEPARTMENT)',
#    'BasePay': 130457.95,
#    'OvertimePay': 27678.4,
#    'OtherPay': 13272.92,
#    'TotalPay': 171409.27,
#    'TotalPayBenefits': 171409.27,
#    'Year': 2011}],
#  'LAURIE JURKIEWICZ': [{'JobTitle': 'NURSE MIDWIFE',
#    'BasePay': 99691.31,
#    'OvertimePay': 0.0,
#    'OtherPay': 71668.16,
#    'TotalPay': 171359.47,
#    'TotalPayBenefits': 171359.47,
#    'Year': 2011}],
#  'DOROTHY QUAN': [{'JobTitle': 'NURSE MANAGER',
#    'BasePay': 154939.5,
#    'OvertimePay': 0.0,
#    'OtherPay': 16403.96,
#    'TotalPay': 171343.46,
#    'TotalPayBenefits': 171343.46,
#    'Year': 2011}],
#  'SHERYL CALSON': [{'JobTitle': 'CLINICAL NURSE SPECIALIST',
#    'BasePay': 169572.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 1521.4,
#    'TotalPay': 171093.4,
#    'TotalPayBenefits': 171093.4,
#    'Year': 2011}],
#  'MATTHEW ALBA': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 105934.65,
#    'OvertimePay': 42119.67,
#    'OtherPay': 23008.92,
#    'TotalPay': 171063.24,
#    'TotalPayBenefits': 171063.24,
#    'Year': 2011}],
#  'CATHERINE DODD': [{'JobTitle': 'DEPARTMENT HEAD III',
#    'BasePay': 171060.82,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 171060.82,
#    'TotalPayBenefits': 171060.82,
#    'Year': 2011}],
#  'FERDINAND DIMAPASOC': [{'JobTitle': 'POLICE OFFICER III',
#    'BasePay': 112401.08,
#    'OvertimePay': 16677.51,
#    'OtherPay': 41951.88,
#    'TotalPay': 171030.47,
#    'TotalPayBenefits': 171030.47,
#    'Year': 2011}],
#  'BRIAN HENDERSON': [{'JobTitle': 'PRINCIPAL CIVIL ENGINEER',
#    'BasePay': 159498.81,
#    'OvertimePay': 0.0,
#    'OtherPay': 11488.66,
#    'TotalPay': 170987.47,
#    'TotalPayBenefits': 170987.47,
#    'Year': 2011}],
#  'KAEO NACUA': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 105934.65,
#    'OvertimePay': 47854.4,
#    'OtherPay': 17184.35,
#    'TotalPay': 170973.4,
#    'TotalPayBenefits': 170973.4,
#    'Year': 2011}],
#  'JEANINE NICHOLSON': [{'JobTitle': 'LIEUTENANT, FIRE DEPARTMENT',
#    'BasePay': 140441.88,
#    'OvertimePay': 17148.2,
#    'OtherPay': 13337.78,
#    'TotalPay': 170927.86,
#    'TotalPayBenefits': 170927.86,
#    'Year': 2011}],
#  'EDWARD LONDONO': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 105934.67,
#    'OvertimePay': 47863.3,
#    'OtherPay': 17111.75,
#    'TotalPay': 170909.72,
#    'TotalPayBenefits': 170909.72,
#    'Year': 2011}],
#  'JAMIE YOUNG': [{'JobTitle': 'ELECTRICAL TRANSIT MECHANIC SUPERVISOR I',
#    'BasePay': 102868.73,
#    'OvertimePay': 63114.86,
#    'OtherPay': 4921.49,
#    'TotalPay': 170905.08,
#    'TotalPayBenefits': 170905.08,
#    'Year': 2011}],
#  'ELIZABETH POTTER': [{'JobTitle': 'MANAGER V',
#    'BasePay': 160812.19,
#    'OvertimePay': 0.0,
#    'OtherPay': 10088.57,
#    'TotalPay': 170900.76,
#    'TotalPayBenefits': 170900.76,
#    'Year': 2011}],
#  'STEVEN SETO': [{'JobTitle': 'TRANSIT SUPERVISOR',
#    'BasePay': 89056.93,
#    'OvertimePay': 75883.5,
#    'OtherPay': 5954.23,
#    'TotalPay': 170894.66,
#    'TotalPayBenefits': 170894.66,
#    'Year': 2011}],
#  'TRACY MCCRAY': [{'JobTitle': 'SERGEANT III (POLICE DEPARTMENT)',
#    'BasePay': 130481.55,
#    'OvertimePay': 10477.85,
#    'OtherPay': 29920.14,
#    'TotalPay': 170879.54,
#    'TotalPayBenefits': 170879.54,
#    'Year': 2011}],
#  'JONATHAN FERDON': [{'JobTitle': 'ATTORNEY FOR THE PUBLIC ADMINISTRATOR',
#    'BasePay': 170844.78,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 170844.78,
#    'TotalPayBenefits': 170844.78,
#    'Year': 2011}],
#  'ART RUIZ': [{'JobTitle': 'FIRE FIGHTER PARAMEDIC',
#    'BasePay': 122404.99,
#    'OvertimePay': 33452.52,
#    'OtherPay': 14928.48,
#    'TotalPay': 170785.99,
#    'TotalPayBenefits': 170785.99,
#    'Year': 2011}],
#  'TIMOTHY FLAHERTY': [{'JobTitle': 'SERGEANT III (POLICE DEPARTMENT)',
#    'BasePay': 130481.53,
#    'OvertimePay': 15154.59,
#    'OtherPay': 25139.73,
#    'TotalPay': 170775.85,
#    'TotalPayBenefits': 170775.85,
#    'Year': 2011}],
#  'ALBERT WATERS II': [{'JobTitle': 'CHIEF DEPUTY SHERIFF',
#    'BasePay': 153172.6,
#    'OvertimePay': 5483.94,
#    'OtherPay': 12092.9,
#    'TotalPay': 170749.44,
#    'TotalPayBenefits': 170749.44,
#    'Year': 2011}],
#  'SEAN OLEARY': [{'JobTitle': 'LIEUTENANT III (POLICE DEPARTMENT)',
#    'BasePay': 134097.91,
#    'OvertimePay': 26626.3,
#    'OtherPay': 9980.44,
#    'TotalPay': 170704.65,
#    'TotalPayBenefits': 170704.65,
#    'Year': 2011}],
#  'ALFREDO SOLIS-SALCAZAR': [{'JobTitle': 'ELECTRICAL TRANSIT SYSTEM MECHANIC',
#    'BasePay': 78067.61,
#    'OvertimePay': 82044.45,
#    'OtherPay': 10541.95,
#    'TotalPay': 170654.01,
#    'TotalPayBenefits': 170654.01,
#    'Year': 2011}],
#  'JUDITH SANSONE': [{'JobTitle': 'NURSING SUPERVISOR',
#    'BasePay': 155189.98,
#    'OvertimePay': 0.0,
#    'OtherPay': 15453.68,
#    'TotalPay': 170643.66,
#    'TotalPayBenefits': 170643.66,
#    'Year': 2011}],
#  'JAMES DRAPER': [{'JobTitle': 'LIEUTENANT, FIRE DEPARTMENT',
#    'BasePay': 128742.45,
#    'OvertimePay': 24428.01,
#    'OtherPay': 17447.21,
#    'TotalPay': 170617.67,
#    'TotalPayBenefits': 170617.67,
#    'Year': 2011}],
#  'JOE CHEUNG': [{'JobTitle': 'PRINCIPAL CIVIL ENGINEER',
#    'BasePay': 170572.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 170572.0,
#    'TotalPayBenefits': 170572.0,
#    'Year': 2011}],
#  'DONALD CHAN': [{'JobTitle': 'PRINCIPAL CIVIL ENGINEER',
#    'BasePay': 162441.06,
#    'OvertimePay': 0.0,
#    'OtherPay': 8098.75,
#    'TotalPay': 170539.81,
#    'TotalPayBenefits': 170539.81,
#    'Year': 2011}],
#  'GABRIEL SHIN': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 105934.68,
#    'OvertimePay': 47640.85,
#    'OtherPay': 16904.8,
#    'TotalPay': 170480.33,
#    'TotalPayBenefits': 170480.33,
#    'Year': 2011}],
#  'MOJGAN YOUSEFKHAN': [{'JobTitle': 'PRINCIPAL CIVIL ENGINEER',
#    'BasePay': 162362.78,
#    'OvertimePay': 0.0,
#    'OtherPay': 8112.38,
#    'TotalPay': 170475.16,
#    'TotalPayBenefits': 170475.16,
#    'Year': 2011}],
#  'TERRY SMERDEL': [{'JobTitle': 'LIEUTENANT, FIRE DEPARTMENT',
#    'BasePay': 124863.62,
#    'OvertimePay': 31978.14,
#    'OtherPay': 13593.7,
#    'TotalPay': 170435.46,
#    'TotalPayBenefits': 170435.46,
#    'Year': 2011}],
#  'MATTHEW LANE': [{'JobTitle': 'FIRE FIGHTER PARAMEDIC',
#    'BasePay': 116781.05,
#    'OvertimePay': 45173.46,
#    'OtherPay': 8430.27,
#    'TotalPay': 170384.78,
#    'TotalPayBenefits': 170384.78,
#    'Year': 2011}],
#  'LARRY CAMILLERI': [{'JobTitle': 'INSPECTOR III, (POLICE DEPARTMENT)',
#    'BasePay': 69076.0,
#    'OvertimePay': 21434.52,
#    'OtherPay': 79863.62,
#    'TotalPay': 170374.14,
#    'TotalPayBenefits': 170374.14,
#    'Year': 2011}],
#  'DAVID ELLIOTT': [{'JobTitle': 'INSPECTOR III, (POLICE DEPARTMENT)',
#    'BasePay': 130457.96,
#    'OvertimePay': 9086.08,
#    'OtherPay': 30801.33,
#    'TotalPay': 170345.37,
#    'TotalPayBenefits': 170345.37,
#    'Year': 2011}],
#  'DOUGLAS SPIKES': [{'JobTitle': 'FIRE FIGHTER PARAMEDIC',
#    'BasePay': 122404.98,
#    'OvertimePay': 32584.75,
#    'OtherPay': 15277.8,
#    'TotalPay': 170267.53,
#    'TotalPayBenefits': 170267.53,
#    'Year': 2011}],
#  'GABRIEL ALCARAZ': [{'JobTitle': 'POLICE OFFICER II',
#    'BasePay': 110118.84,
#    'OvertimePay': 32981.9,
#    'OtherPay': 27162.71,
#    'TotalPay': 170263.45,
#    'TotalPayBenefits': 170263.45,
#    'Year': 2011}],
#  'VALERIE MATTHEWS': [{'JobTitle': 'INSPECTOR III, (POLICE DEPARTMENT)',
#    'BasePay': 130466.58,
#    'OvertimePay': 20619.01,
#    'OtherPay': 19145.69,
#    'TotalPay': 170231.28,
#    'TotalPayBenefits': 170231.28,
#    'Year': 2011}],
#  'EUGENE CLENDINEN': [{'JobTitle': 'MANAGER VIII',
#    'BasePay': 161479.27,
#    'OvertimePay': 0.0,
#    'OtherPay': 8750.1,
#    'TotalPay': 170229.37,
#    'TotalPayBenefits': 170229.37,
#    'Year': 2011}],
#  'EDWARD BROWNE': [{'JobTitle': 'POLICE OFFICER III',
#    'BasePay': 112401.08,
#    'OvertimePay': 7430.89,
#    'OtherPay': 50391.05,
#    'TotalPay': 170223.02,
#    'TotalPayBenefits': 170223.02,
#    'Year': 2011}],
#  'WILLIAM WYCKOFF': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 105934.64,
#    'OvertimePay': 52697.7,
#    'OtherPay': 11553.27,
#    'TotalPay': 170185.61,
#    'TotalPayBenefits': 170185.61,
#    'Year': 2011}],
#  'CHARLES MC COY': [{'JobTitle': 'LIEUTENANT, FIRE DEPARTMENT',
#    'BasePay': 123105.0,
#    'OvertimePay': 31227.51,
#    'OtherPay': 15842.22,
#    'TotalPay': 170174.73,
#    'TotalPayBenefits': 170174.73,
#    'Year': 2011}],
#  'MICHAEL HASTEY': [{'JobTitle': 'FIRE FIGHTER PARAMEDIC',
#    'BasePay': 122405.0,
#    'OvertimePay': 32171.52,
#    'OtherPay': 15551.55,
#    'TotalPay': 170128.07,
#    'TotalPayBenefits': 170128.07,
#    'Year': 2011}],
#  'PEIYUE HO': [{'JobTitle': 'DIAGNOSTIC IMAGING TECH II',
#    'BasePay': 103971.4,
#    'OvertimePay': 23945.61,
#    'OtherPay': 42208.3,
#    'TotalPay': 170125.31,
#    'TotalPayBenefits': 170125.31,
#    'Year': 2011}],
#  'CAROL WOLTHER': [{'JobTitle': 'ELECTRICAL TRANSIT SHOP SUPERVISOR I',
#    'BasePay': 109160.81,
#    'OvertimePay': 43092.79,
#    'OtherPay': 17859.01,
#    'TotalPay': 170112.61,
#    'TotalPayBenefits': 170112.61,
#    'Year': 2011}],
#  'KENNETH LOMBARDI': [{'JobTitle': 'CAPTAIN, FIRE SUPPRESSION',
#    'BasePay': 135103.4,
#    'OvertimePay': 23598.47,
#    'OtherPay': 11377.28,
#    'TotalPay': 170079.15,
#    'TotalPayBenefits': 170079.15,
#    'Year': 2011}],
#  'DANIEL COLE': [{'JobTitle': 'SERGEANT III (POLICE DEPARTMENT)',
#    'BasePay': 131715.02,
#    'OvertimePay': 5201.24,
#    'OtherPay': 33112.94,
#    'TotalPay': 170029.2,
#    'TotalPayBenefits': 170029.2,
#    'Year': 2011}],
#  'DOUGLAS PRICE-HANSON': [{'JobTitle': 'PHYSICIAN SPECIALIST',
#    'BasePay': 159511.95,
#    'OvertimePay': 0.0,
#    'OtherPay': 10513.63,
#    'TotalPay': 170025.58,
#    'TotalPayBenefits': 170025.58,
#    'Year': 2011},
#   {'JobTitle': 'SENIOR PHYSICIAN SPECIALIST',
#    'BasePay': 29576.4,
#    'OvertimePay': 0.0,
#    'OtherPay': 1373.19,
#    'TotalPay': 30949.59,
#    'TotalPayBenefits': 30949.59,
#    'Year': 2011}],
#  'SUSAN OBATA': [{'JobTitle': 'SUPERVISING PHYSICIAN SPECIALIST',
#    'BasePay': 169941.65,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 169941.65,
#    'TotalPayBenefits': 169941.65,
#    'Year': 2011}],
#  'RICHARD THOMPSON': [{'JobTitle': 'SENIOR DEPUTY SHERIFF',
#    'BasePay': 96252.08,
#    'OvertimePay': 64426.82,
#    'OtherPay': 9244.04,
#    'TotalPay': 169922.94,
#    'TotalPayBenefits': 169922.94,
#    'Year': 2011}],
#  'LOUIS ESPINDA': [{'JobTitle': 'LIEUTENANT III (POLICE DEPARTMENT)',
#    'BasePay': 149050.78,
#    'OvertimePay': 6220.38,
#    'OtherPay': 14638.5,
#    'TotalPay': 169909.66,
#    'TotalPayBenefits': 169909.66,
#    'Year': 2011}],
#  'DAMEN TOLLIVER': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 105934.64,
#    'OvertimePay': 54436.25,
#    'OtherPay': 9533.84,
#    'TotalPay': 169904.73,
#    'TotalPayBenefits': 169904.73,
#    'Year': 2011}],
#  'GRACE SALUD': [{'JobTitle': 'NURSE MANAGER',
#    'BasePay': 156312.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 13587.12,
#    'TotalPay': 169899.12,
#    'TotalPayBenefits': 169899.12,
#    'Year': 2011},
#   {'JobTitle': 'SPECIAL NURSE',
#    'BasePay': 2671.38,
#    'OvertimePay': 0.0,
#    'OtherPay': 145.02,
#    'TotalPay': 2816.4,
#    'TotalPayBenefits': 2816.4,
#    'Year': 2011}],
#  'YUSUFU CAUNGULA': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 105934.67,
#    'OvertimePay': 53551.86,
#    'OtherPay': 10357.93,
#    'TotalPay': 169844.46,
#    'TotalPayBenefits': 169844.46,
#    'Year': 2011}],
#  'ANTIONETTE GRIFFIN': [{'JobTitle': 'CLINICAL NURSE SPECIALIST',
#    'BasePay': 169572.08,
#    'OvertimePay': 0.0,
#    'OtherPay': 250.0,
#    'TotalPay': 169822.08,
#    'TotalPayBenefits': 169822.08,
#    'Year': 2011}],
#  'KATHERINE MAH': [{'JobTitle': 'CLINICAL NURSE SPECIALIST',
#    'BasePay': 169572.06,
#    'OvertimePay': 0.0,
#    'OtherPay': 250.0,
#    'TotalPay': 169822.06,
#    'TotalPayBenefits': 169822.06,
#    'Year': 2011}],
#  'CHRISTINE DAVENPORT': [{'JobTitle': 'CLINICAL NURSE SPECIALIST',
#    'BasePay': 169572.05,
#    'OvertimePay': 0.0,
#    'OtherPay': 250.0,
#    'TotalPay': 169822.05,
#    'TotalPayBenefits': 169822.05,
#    'Year': 2011}],
#  'ANNE HUGHES': [{'JobTitle': 'CLINICAL NURSE SPECIALIST',
#    'BasePay': 169572.01,
#    'OvertimePay': 0.0,
#    'OtherPay': 250.0,
#    'TotalPay': 169822.01,
#    'TotalPayBenefits': 169822.01,
#    'Year': 2011}],
#  'JOHN FAZIO': [{'JobTitle': 'CLINICAL NURSE SPECIALIST',
#    'BasePay': 169572.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 250.0,
#    'TotalPay': 169822.0,
#    'TotalPayBenefits': 169822.0,
#    'Year': 2011},
#   {'JobTitle': 'SPECIAL NURSE',
#    'BasePay': 26943.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 2717.43,
#    'TotalPay': 29660.43,
#    'TotalPayBenefits': 29660.43,
#    'Year': 2011}],
#  'ROBERT KUZMA': [{'JobTitle': 'CAPTAIN, EMERGENCYCY MEDICAL SERVICES',
#    'BasePay': 140546.84,
#    'OvertimePay': 8577.69,
#    'OtherPay': 20692.86,
#    'TotalPay': 169817.39,
#    'TotalPayBenefits': 169817.39,
#    'Year': 2011}],
#  'DIANE CARR': [{'JobTitle': 'NURSE PRACTITIONER',
#    'BasePay': 169520.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 250.0,
#    'TotalPay': 169770.0,
#    'TotalPayBenefits': 169770.0,
#    'Year': 2011}],
#  'SHOTSY FAUST': [{'JobTitle': 'NURSE PRACTITIONER',
#    'BasePay': 169520.0,
#    'OvertimePay': 0.0,
#    'OtherPay': 250.0,
#    'TotalPay': 169770.0,
#    'TotalPayBenefits': 169770.0,
#    'Year': 2011}],
#  'DIANE KNOLES': [{'JobTitle': 'ATTORNEY (CIVIL/CRIMINAL)',
#    'BasePay': 167240.64,
#    'OvertimePay': 0.0,
#    'OtherPay': 2528.53,
#    'TotalPay': 169769.17,
#    'TotalPayBenefits': 169769.17,
#    'Year': 2011}],
#  'ERIC FLEMING': [{'JobTitle': 'HEAD ATTORNEY, CIVIL AND CRIMINAL',
#    'BasePay': 169647.29,
#    'OvertimePay': 0.0,
#    'OtherPay': 0.0,
#    'TotalPay': 169647.29,
#    'TotalPayBenefits': 169647.29,
#    'Year': 2011}],
#  'CHRISTOPHER DUGAN': [{'JobTitle': 'FIREFIGHTER',
#    'BasePay': 105934.64,
#    'OvertimePay': 48209.91,
#    'OtherPay': 15364.97,
#    'TotalPay': 169509.52,
#    'TotalPayBenefits': 169509.52,
#    'Year': 2011}],
#  'LEONARD CAULDER': [{'JobTitle': 'FIRE FIGHTER PARAMEDIC',
#    'BasePay': 122283.44,
#    'OvertimePay': 31623.64,
#    'OtherPay': 15536.35,
#    'TotalPay': 169443.43,
#    'TotalPayBenefits': 169443.43,
#    'Year': 2011}],
#  'JOSEPH PACE': [{'JobTitle': 'SUPERVISING PHYSICIAN SPECIALIST',
#    'BasePay': 168950.01,
#    'OvertimePay': 0.0,
#    'OtherPay': 405.0,
#    'TotalPay': 169355.01,
#    'TotalPayBenefits': 169355.01,
#    'Year': 2011}],
#  ...}

# %%
#Error handling

try:
# Load the salary data file
    file_path = "Total.csv"
    df = pd.read_csv(file_path)
    
# Convert "Not Provided" to NaN
    df.replace("Not Provided", pd.NA, inplace=True)
    
# Convert salary-related columns to numeric values
    salary_columns = ["BasePay", "OvertimePay", "OtherPay", "TotalPay", "TotalPayBenefits"]
    df[salary_columns] = df[salary_columns].apply(pd.to_numeric, errors="coerce")
    
# Create a salary dictionary
    salary_dict = {}
    for _, row in df.iterrows():
        try:
            name = row["EmployeeName"]
            record = {
                "JobTitle": row["JobTitle"],
                "BasePay": row["BasePay"],
                "OvertimePay": row["OvertimePay"],
                "OtherPay": row["OtherPay"],
                "TotalPay": row["TotalPay"],
                "TotalPayBenefits": row["TotalPayBenefits"],
                "Year": row["Year"],
            }
            
            if name in salary_dict:
                salary_dict[name].append(record)
            else:
                salary_dict[name] = [record]
        except KeyError as e:
            print(f"Missing expected column in row: {e}")
        except Exception as e:
            print(f"Unexpected error processing row: {e}")
    
# Display a sample entry
    print(list(salary_dict.items())[:3])
except FileNotFoundError:
    print("Error: The file 'Total.csv' was not found.")
except pd.errors.EmptyDataError:
    print("Error: The file is empty.")
except pd.errors.ParserError:
    print("Error: There was an issue parsing the file.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# C:\Users\ElishaAbelMagobo\AppData\Local\Temp\ipykernel_12548\3489718993.py:4: DtypeWarning: Columns (2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# [('NATHANIEL FORD', [{'JobTitle': 'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', 'BasePay': 167411.18, 'OvertimePay': 0.0, 'OtherPay': 400184.25, 'TotalPay': 567595.43, 'TotalPayBenefits': 567595.43, 'Year': 2011}]), ('GARY JIMENEZ', [{'JobTitle': 'CAPTAIN III (POLICE DEPARTMENT)', 'BasePay': 155966.02, 'OvertimePay': 245131.88, 'OtherPay': 137811.38, 'TotalPay': 538909.28, 'TotalPayBenefits': 538909.28, 'Year': 2011}]), ('ALBERT PARDINI', [{'JobTitle': 'CAPTAIN III (POLICE DEPARTMENT)', 'BasePay': 212739.13, 'OvertimePay': 106088.18, 'OtherPay': 16452.6, 'TotalPay': 335279.91, 'TotalPayBenefits': 335279.91, 'Year': 2011}])]

# %%
# Convert dictionary to DataFrame and save to CSV
salary_list = []
for name, records in salary_dict.items():
    for record in records:
        record["EmployeeName"] = name
        salary_list.append(record)
    
    output_df = pd.DataFrame(salary_list)
    output_df.to_csv("Processed_Salary_Data.csv", index=False)
    
print("Processed salary data saved to 'Processed_Salary_Data.csv'")
